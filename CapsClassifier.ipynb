# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.externals import joblib
from CapsVectorizer import CapsVectorizer
import pandas as pd
import numpy as np

# %%
# Load data
# Fake news is 1. Real news is 0.
df = pd.read_csv("dataset/data_clean.csv")

# %%
data = df.sample(frac=1).reset_index(drop=True)

# %%
df_train, df_test = train_test_split(data, test_size=0.50)
print(df_train.shape)
print(df_test.shape)
sum(data['label'])
# Out:
# (5677, 6)
# (5678, 6)
# 5677

# %%
count_vect = CapsVectorizer()
X_train_counts = count_vect.fit_transform(df_train['text'])
print(X_train_counts.shape)

X_test_counts = count_vect.transform(df_test['text'])
print(X_test_counts.shape)

mnb_clf = MultinomialNB().fit(X_train_counts, df_train['label'])
svm_clf = LinearSVC().fit(X_train_counts, df_train['label'])
# Out:
# ['NBCU']
# ['FILE', 'PHOTO', 'PBOC', 'REUTERS', 'FILE', 'PHOTO', 'PBOC', 'REUTERS', 'BEIJING', 'PBOC', 'PBOC', 'PBOC', 'PBOC', 'CFXS', 'PBOC', 'TURTLES', 'PBOC']
# ['HACKENSACK']
# ['LGBTQ']
# ['BDSM']
# ['LCSW', 'LCSW']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# ['FAVOR', 'AGAINST']
# ['REUTERS', 'REUTERS', 'LONDON', 'TROUBLE', 'AHEAD']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON']
# ['JUST', 'WATCHED', 'MUST', 'WATCH']
# ['FILE', 'PHOTO', 'NYSE', 'REUTERS', 'FILE', 'PHOTO', 'NYSE', 'REUTERS', 'ULVR']
# ['REUTERS', 'REUTERS', 'YANGON', 'WHITEWASH', 'YANGON', 'DHAKA', 'MANILA', 'WASHINGTON']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK', 'FOMC']
# []
# ['TIME', 'NAACP', 'THINK']
# []
# []
# ['ISMOYO', 'BNPB']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON']
# []
# ['REUTERS', 'REUTERS']
# ['REUTERS', 'REUTERS', 'BERN', 'FLEXIBILITY']
# []
# []
# ['OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# []
# []
# ['AIDS', 'LGBT']
# []
# ['REUTERS', 'REUTERS', 'BERLIN']
# ['REUTERS', 'REUTERS', 'YANGON', 'VATICAN', 'DIPLOMACY', 'INFALLIBLE']
# ['MONTHS', 'ENTIRE', 'CHRISTMAS', 'SHOW', 'STRONG', 'ABLE', 'YOUR', 'YOUR']
# []
# ['REUTERS', 'REUTERS', 'SALZBURG', 'COLD', 'SHOULDER']
# ['ARLINGTON']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'BAGHDAD', 'KURDISH', 'REFERENDUM']
# []
# ['REUTERS', 'REUTERS', 'SEOUL', 'BIGGER', 'DRILLS']
# []
# ['WASHINGTON']
# ['LULAC']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'FRANCISCO']
# []
# ['REUTERS', 'REUTERS', 'BEIJING']
# []
# ['REUTERS', 'REUTERS', 'LSEG']
# []
# ['DACA']
# ['NASA', 'DSLR']
# ['FISA']
# ['ALSO', 'ALSO', 'PHOTOS', 'ALSO', 'LADIES', 'ALSO', 'PHOTOS']
# ['KANPUR', 'UPSERC']
# []
# ['BREAKING']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'WASHINGTON', 'NDAA', 'NDAA', 'THAAD', 'THAAD']
# []
# ['READ', 'MORE']
# ['NAFTA']
# []
# ['SNAPCHAT', 'SOCIAL', 'MEDIA', 'FUELED', 'RISE', 'FAKE', 'NEWS']
# ['THINKSTOCK', 'THINKSTOCK', 'THINKSTOCK', 'THINKSTOCK']
# ['BREAKING']
# ['TODAY', 'TODAY', 'LPGA', 'LPGA']
# []
# ['DOES', 'JUST', 'ISIS']
# []
# ['KQED', 'KQED']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'HONG', 'KONG', 'BABA', 'BABA']
# []
# []
# []
# []
# []
# []
# ['DACA']
# ['YORK', 'NFLPA', 'NFLPA']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'BARCELONA', 'RFEF']
# ['INSCOM', 'INSCOM']
# []
# ['VARIETY', 'PUZZLE', 'CAPOTE', 'FISHEYE', 'CLUB', 'HERO', 'CHROMOSOME']
# ['REUTERS', 'REUTERS', 'ANGELES']
# ['SHARES', 'HOME', 'NEWS', 'POLITICS', 'INFO', 'NEWS']
# ['CNBC']
# ['ESPN', 'REUTERS', 'ESPN', 'REUTERS', 'ESPN', 'ESPN']
# []
# []
# ['MSNBC']
# ['LGBTQ', 'LGBTQ', 'LGBTQ', 'LGBTQ', 'LGBTQ', 'LGBTQ']
# ['ISIS', 'ISIS', 'IJOC', 'ISIS', 'ISIS', 'ISIS']
# ['KARMA']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'SEOUL', 'UNITED', 'NATIONS', 'CLOCK', 'TICKING', 'ICBM', 'DPRK', 'ICBM']
# ['REUTERS', 'REUTERS', 'BEIRUT', 'RESTRICTED', 'FREEDOM', 'SAUDI', 'ARRESTS']
# ['BRUSSELS']
# []
# ['READ', 'MORE']
# []
# []
# []
# []
# ['XIII', 'VOICES']
# ['SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'LIFE', 'VISTA', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'SWAT', 'UASI', 'UASI', 'UASI', 'SWAT', 'UASI', 'UASI', 'SWAT', 'SWAT', 'SWAT']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'CNBC', 'CNBC', 'CNBC', 'CNBC', 'ESPN', 'CNBC', 'ESPN']
# []
# ['UNIAN', 'META']
# []
# ['NASA']
# ['ICBM']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'OTTAWA']
# []
# ['LGBT', 'LGBT']
# []
# []
# ['REACTION', 'KPIX']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# []
# ['MORE', 'HERE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'HONG', 'KONG', 'AAPL', 'LOSING', 'STEAM']
# ['WASHINGTON']
# ['REUTERS', 'REUTERS', 'BANGKOK', 'PERSECUTION']
# ["GOP'", 'REUTERS', 'ERLC', 'ERLC']
# ['MSNBC', 'MSNBC']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# []
# []
# []
# ['ZANU', 'REUTERS', 'ZANU', 'REUTERS', 'HARARE', 'ZANU', 'ZANU']
# ['MORE', 'HERE']
# []
# ['NATURAL', 'OATS', 'CPPA']
# ['CONVICTIONS', 'RINO', 'KRQE', 'MSNBC']
# ['FILE', 'PHOTO', 'UNITA', 'REUTERS', 'FILE', 'PHOTO', 'UNITA', 'REUTERS', 'LUANDA', 'UNITA', 'MPLA', 'UNITA', 'MPLA', 'UNITA', 'UNITA', 'CASA', 'UNITA', 'MPLA', 'MPLA', 'ELECTION', 'MONITORING', 'UNITA', 'UNITA', 'UNITA', 'UNITA', 'UNITA', 'UNITA', 'UNITA']
# ['PLUS', 'WILD', 'FREE']
# []
# []
# []
# []
# ['LOVE', 'STEVE']
# []
# ['ISIS', 'ISIS']
# ['REUTERS']
# []
# []
# ['REUTERS', 'ELGAMOUDI', 'REUTERS']
# []
# ['VIEW', 'GALLERY']
# ['WASHINGTON']
# []
# []
# []
# []
# ['MOSCOW', 'MEDIA', "WADA'", 'READ', 'MORE', 'WADA', 'RUSADA', 'READ', 'MORE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ROME']
# ['SEOUL']
# ['RELATED', 'ARTICLES']
# ["RBS'"]
# ["CNN'", 'YMCA']
# []
# []
# []
# []
# []
# []
# []
# []
# ['TRENDING', 'MSNBC', 'RELATED']
# []
# ["CNN'", "CNN'", "CNN'"]
# ['REUTERS', 'REUTERS', 'ANGELES', 'IMAX', 'IMAX']
# []
# ['SCROLL', 'DOWN', 'VIDEO']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'GUATEMALA', 'CITY', 'CICIG', 'CICIG', 'CICIG', 'CICIG', 'CICIG']
# []
# ['FSMA', 'FSMA', 'FSMA', 'FSMA', 'FSMA', 'FSMA']
# ["NBC'"]
# []
# ['VEJA', 'RECORDES', 'NOCAUTES', 'RECORDES', 'OUTROS', 'LINKS', 'RANKINGS', 'RANKINGS', 'RANKINGS', 'RANKINGS']
# ['FIFA', 'FIFA', 'UEFA']
# ['BAFTA', 'REUTERS', 'BAFTA', 'REUTERS', 'YORK']
# []
# []
# ['REUTERS', "FBI'", "FBI'", 'WARNING', 'ARTICLE', 'ABOVE', 'WORK', 'SATIRE', 'PLEASE', 'SHARE', 'RESPONSIBLY']
# []
# []
# []
# []
# []
# []
# ['MSNBC', 'MSNBC', 'MSNBC', 'MSNBC', 'MSNBC', 'MSNBC', 'MSNBC', 'MSNBC', 'MSNBC']
# ['NAACP']
# []
# []
# ['THAT', 'SUCH']
# []
# []
# ['BREAKING', 'OVERNIGHT']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# ['RIGHTS', 'RESERVED']
# []
# []
# ['PITTSBURGH', 'ESPN']
# ['REUTERS', 'REUTERS', 'BERLIN']
# ['REUTERS', 'REUTERS', 'BENGHAZI']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MANILA', 'APEC']
# ['REUTERS', 'REUTERS', 'YORK']
# ['JUST', 'WATCHED', 'MUST', 'WATCH', 'ISIS']
# []
# ['CLICK', 'HERE', 'LIKE', 'DAILY', 'BUZZ', 'LIVE', 'FACEBOOK']
# ['NIST']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ISTANBUL', 'NATO']
# ['REUTERS', 'REUTERS', 'BEIJING', 'FCHA']
# []
# []
# []
# []
# ['REUTERS', 'ASEAN']
# ['THREE', 'TREASURES', 'ESSENCE', 'ENERGY', 'SPIRIT', 'VIVO', 'VIVO', 'VIVO']
# ['LGBT', 'LGBT', 'LGBT', 'LGBT']
# ['EXISTING', 'STRUCTURES', 'PROPOSED', 'STRUCTURES', 'EXISTING', 'STRUCTURES', 'PROPOSED', 'STRUCTURES']
# ['ACLU']
# ['MSNBC']
# ['REUTERS', 'FLOTUS']
# ['REUTERS', 'REUTERS', 'PHOENIX']
# ['FDIC']
# []
# []
# ['ARTIST', 'YEAR', 'ALBUM', 'YEAR', 'CONGRATULATIONS', 'WINNERS']
# []
# []
# []
# []
# ['LGBT', 'LGBT', 'LGBT']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'JAKARTA']
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'NYSE']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ANGELES']
# ['MARCOTTE', 'ADHD']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIJING']
# ['REUTERS', 'REUTERS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIRUT', 'TASS']
# []
# []
# ['WCVB']
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'CFRA']
# ['APEC', 'REUTERS', 'APEC', 'REUTERS', 'HANOI']
# ['KGTV', 'RELATED']
# ['DAMASCUS']
# ['REUTERS', 'REUTERS', 'ZHUHAI']
# []
# ['REUTERS', 'REUTERS', 'KARACHI', 'NATO', 'AMERICA', 'ENEMY']
# ['ALERT']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SEOUL', 'SSIC', 'SSIC']
# []
# []
# ['WSCLT', 'QCFT', 'QCFT', 'QCFT', 'QCFT']
# []
# ['ISIS', 'FOTO', 'REUTERS', 'MUHAMMAD', 'HAMED', 'ISIS', 'ISIL', 'ISIS', 'ISIS']
# []
# ['REUTERS', 'REUTERS', 'OSAN']
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'UNITED', 'NATIONS', 'OPCW']
# ['FILE', 'PHOTO', 'LPGA', 'REUTERS', 'FILE', 'PHOTO', 'LPGA', 'REUTERS', 'LPGA']
# []
# ['LGBTQ']
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'IXIC', 'SPLRCS', 'AMZN', 'DLTR', 'NYSE']
# ['ELBJAZZ', 'ELBJAZZ']
# []
# []
# ['SHARES', 'BREAKING']
# ["STI'", "STI'"]
# ['WASP', 'NASA', 'WASP', 'NASA', 'WASP', 'WASP']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'KARACHI']
# ['BREAKING']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['AUSTRALIA', 'NISA']
# ['REUTERS', 'STEVE', 'DIPAOLA']
# ['LGBT', 'LGBT', 'KHNT', 'LGBT']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['REUTERS', 'REUTERS', 'SYDNEY']
# ['PHONE', 'CONVERSATION', 'LATE', 'LAST', 'WEEK', 'VOIGHT', 'CONFIRMED', 'DAILY', 'BEAST', 'THAT', 'TEAM', 'TRUMP', 'HAVE', 'BEEN', 'COMMUNICATING', 'RECENT', 'WEEKS', 'ABOUT', 'POTENTIALLY', 'DEPLOYING', 'VOIGHT', 'STAR', 'POWER', 'CAMPAIGN', 'TRAIL', 'POSSIBLY', 'REPUBLICAN', 'NATIONAL', 'CONVENTION', 'CLEVELAND', 'THIS', 'JULY', 'HELPFUL', 'VOIGHT', 'SAID', 'INTEND', 'COME', 'CONVENTION', 'TIME', 'TRUMP', 'CAMPAIGN', 'WANTS', 'CONVENTION', 'THEY', 'MAKE', 'PLANS', 'FROM', 'THERE', 'WOULD', 'LIKE', 'SUPPORT', 'THAT', 'TOUCH', 'WITH', 'CAMPAIGN', 'FULLY', 'SUPPORT', 'DONALD', 'THINK', 'HAVE', 'DISCUSSED', 'WITH', 'THEM', 'POSSIBILITY', 'BEING', 'CONVENTION', 'WHAT', 'MIGHT', 'AVAILABLE', 'THEM', 'CALIFORNIA', 'WHEN', 'ASKED', 'ABOUT', 'WAYS', 'DISCUSSED', 'THAT', 'ACTOR', 'MIGHT', 'BEST', 'TRUMP', 'CAMPAIGN', 'CELEBRITY', 'SURROGACY', 'TRAIL', 'FUNDRAISING', 'PHONE', 'BANKING', 'CUTTING', 'SPEAKING', 'ONSTAGE', 'CONVENTION', 'EASTWOOD', 'FOUR', 'YEARS', 'VOIGHT', 'REPLIED', 'EVERYTHING', 'TABLE', 'GONNA', 'VERY', 'INTERESTING', 'FROM', 'TIME', 'CONVENTION', 'TIME', 'ELECTION', 'WILL', 'CERTAINLY', 'WANT', 'MAKE', 'MYSELF', 'AVAILABLE', 'TRUMP', 'CLOSER', 'ELECTION', 'VOIGHT', 'SAYS', 'THAT', 'TRUMP', 'CONTROVERSIAL', 'RESPONSE', 'MASS', 'SHOOTING', 'PULSE', 'NIGHTCLUB', 'ORLANDO', 'ONLY', 'REINFORCED', 'SUPPORT', 'TRUMP', 'WHITE', 'HOUSE', 'THINK', 'WHAT', 'BEEN', 'SAYING', 'MAJOR', 'PRESS', 'CONFERENCES', 'SPEECHES', 'POST', 'ORLANDO', 'HAVE', 'BEEN', 'APPROPRIATE', 'MAKE', 'VERY', 'GOOD', 'SENSE', 'SAID']
# []
# []
# ['TODAY']
# ['KCNA']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TORONTO']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ANGELES']
# []
# []
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'INVESTOR', 'FRUSTRATION']
# ['VARIETY', 'TODD', 'SPLANGER', 'PHOTO', 'BAUER']
# []
# ['FRIDAY', 'PUZZLE', 'GENDER', 'ROLES']
# ['CRPC']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'REUTERS', 'REUTERS', 'BERLIN', 'ELECTIONS']
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ROME', 'ANTI', 'IMMIGRANT', 'PARTIES', 'GAINING']
# []
# []
# []
# ['PAVEL', 'POLIAN']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'DHABI']
# ['JUST', 'WATCHED', 'MUST', 'WATCH', 'NASA', 'GITEX', 'JUST', 'WATCHED', 'MUST', 'WATCH', 'CCTV']
# ['REUTERS', 'REUTERS', 'TOKYO']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# []
# ["NPR'", "NPR'"]
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'GENEVA']
# ['MISIS', 'NUST', 'MISIS', 'READ', 'MORE', 'NUST', 'MISIS', 'NUST', 'MISIS', 'STROIBIS', 'NUST', 'MISIS', 'READ', 'MORE']
# []
# []
# ['LGBT', 'ARCOTEL', 'ARCOTEL']
# []
# []
# []
# []
# []
# ['FRENCH', 'FRIES', 'HOME', 'ANYTHING', 'SALE']
# []
# ['REUTERS', 'REUTERS', 'ANKARA', 'BAGHDAD', 'ANGRY', 'PEOPLE', 'SHELTER']
# ['NASA', 'NASA', 'NASA', 'NASA', 'STEM', 'STEM']
# []
# ['REUTERS', 'REUTERS', 'WARSAW']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'KUALA', 'LUMPUR', 'SINGAPORE', 'MCMC', 'MVNO', 'LIKE', 'EQUIFAX', 'MXSC', 'AXIA', 'DSOM', 'MCMC', 'ALMOST', 'EVERY', 'MALAYSIAN', 'MVNO']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BERLIN', 'COUNTERMEASURES']
# ['REUTERS', 'REUTERS', 'TOKYO']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'KUWAIT', 'KUNA', 'OPEC']
# ['ICTY', 'REUTERS', 'ICTV']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BERLIN']
# []
# ['ASRC', 'REUTERS', 'ASRC', 'REUTERS', 'WELLINGTON', 'ASRC']
# []
# []
# ['HEADS', 'NASA']
# ['READER', 'SUBMITTED', 'NEWS']
# ['REUTERS', "ABC'"]
# ['TREASON']
# ['LIVE', 'WASHINGTON', 'MVPD', 'PRISM', 'GVTC']
# ['NOAA']
# ['FAILURE', 'PULLED', 'LITERALLY', 'SIMPLE', 'JUST', 'ABOUT', 'MAKING', 'DEALS', 'KNOWING', 'WHEN', 'WALK', 'AWAY', 'FROM', 'DEALS', 'WHEN', 'THERE', 'DEAL', 'THAT', 'ONLY', 'SOLUTION', 'VIDEO', 'BELOW', 'TRAP']
# ['REUTERS', 'REUTERS', 'JERUSALEM']
# ['LGBTI', 'SCBC']
# ['REUTERS', 'REUTERS', 'YORK']
# []
# []
# ['JUST', 'WATCHED', 'MUST', 'WATCH', 'JUST', 'WATCHED', 'MUST', 'WATCH']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK']
# []
# ['NASA']
# ['MSNBC', 'UPDATE']
# ['YOUR']
# ['WORKS', 'TERM', 'ASSASSINATION', 'SHARE', 'THIS']
# ['LEFT', 'LEFT', 'LEFT', 'LEFT', 'LEFT']
# ['AIDS', 'AIDS', 'AIDS', 'UNAIDS', 'AIDS']
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'FRANKFURT']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'JOHANNESBURG']
# []
# ['SHARE']
# ['CNBC']
# ['RUSADA', 'REUTERS', 'RUSADA', 'REUTERS', 'MOSCOW', 'RUSADA', 'WADA', 'RUSADA', 'RUSADA', 'RUSADA', 'RUSADA', 'WADA', 'RUSADA', 'WADA', 'WADA', 'RUSADA', 'WADA', 'RUSADA', 'WADA', 'RUSADA']
# ['COST', 'AMZN']
# []
# []
# ['GOODMAN', 'CARLOTTA', 'GROHMANN', 'KATIA', 'PROMESA', 'GOODMAN', 'KATIA', 'GOODMAN', 'KATIA', 'FEMA', 'MONICA', 'ATKINS', 'CHIEF', 'NINAWA', 'HUNI', 'MIRIAN', 'CISNEROS', 'DARIO', 'KOPPENBERGER', 'GOODMAN']
# []
# []
# []
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'AMZN']
# []
# ['VIDEO', 'KPHO', 'KTVK', 'KPHO']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['EXCLUSIVE']
# ['BHAMO']
# ["CBN'"]
# ['REUTERS', 'REUTERS', 'SANTIAGO']
# ['APTV', 'ISIS', 'ISIS']
# ["CNN'"]
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SYDNEY', 'SUBDUED', 'SPENDING']
# ['SUPPORT', 'INDEPENDENT', 'MEDIA', 'PATREON', 'FACEBOOK', 'INSTAGRAM', 'TWITTER', 'STEEMIT', 'SNAPCHAT']
# []
# ['KCNA', 'JINPING']
# []
# []
# ['ICBM']
# []
# []
# ['SWAT']
# ['REUTERS', 'REUTERS', 'JOHANNESBURG']
# ['LGBTQ', 'FEMA', 'LGBTQ', 'ENLACE', 'BSHF', 'COPI', 'COPI', 'COPI', 'COPI', 'ISER', 'CDPEC', 'ENLACE']
# ['DARPA', 'DARPA', 'ANON', 'JEKLOY']
# ['REUTERS', 'REUTERS', 'BUDAPEST']
# ['TODAY', 'TODAY']
# []
# []
# []
# ['TODAY', 'ESPN']
# []
# ['PUREX']
# ['REUTERS', 'REUTERS', 'BRUSSELS']
# []
# []
# ['ASEAN', 'ASEAN', 'REUTERS', 'ASEAN', 'ASEAN', 'REUTERS', 'MANILA', 'ASEAN', 'ASEAN', 'ASEAN', 'ASEAN', 'SOUTH', 'CHINA', 'WARNING', 'ASEAN', 'ASEAN', 'DUTERTE', 'TRUMP', 'YOUR', 'ALLY', 'MANILA', 'BEIJING']
# []
# []
# ['REUTERS', 'REUTERS', 'ISLAMABAD']
# []
# ['WORLDS', 'UNSOLD', 'STOCKPILE', 'NOTE', 'UPDATE']
# ['REUTERS', 'REUTERS', 'ISLAMABAD']
# ['PRESIDENT', 'UNITED', 'STATES', 'DONALD', 'TRUMP', 'RETWEETED', 'THREE', 'DEPUTY', 'LEADER', 'JAYDA', "FRANSEN'S", 'TWITTER', 'VIDEOS', 'DONALD', 'TRUMP', 'HIMSELF', 'RETWEETED', 'THESE', 'VIDEOS', 'AROUND', 'MILLION', 'FOLLOWERS', 'BLESS', 'TRUMP', 'BLESS', 'AMERICA']
# []
# []
# ['TOKYO']
# ['ISIS']
# []
# []
# ['MSNBC']
# ['REUTERS']
# ['UNICEF', "UNICEF'", 'UNICEF']
# []
# ['THURSDAY', 'PUZZLE', 'AGES', 'TAUTOLOGY', 'TAUTOLOGY', 'TAUTOLOGY']
# ['STEP']
# []
# []
# []
# []
# []
# ['TODAY', 'TODAY']
# []
# []
# []
# []
# []
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'ULTA', 'APRN', 'OPEC']
# []
# ['AMZN', 'AAPL', 'AAPL', 'SSNLF']
# ['ENJOY']
# []
# ['REUTERS', 'REUTERS', 'SEOUL', 'SHROUDED', 'SECRECY']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON']
# ['REUTERS', 'REUTERS', 'YORK', 'RTRX', 'MSMB', 'MSMB']
# ['HERE', 'WHAT', 'WILL', 'HAPPEN', 'DEEP', 'STATE', 'TAKES', 'DOWN', 'PRESIDENT', 'TRUMP', 'PRETTY', 'THEM', 'ELDER', 'PATRIOT', 'EDITORS', 'NOTE', 'THIS', 'CALL', 'ARMS', 'RATHER', 'ANALYSIS', 'WHAT', 'WOULD', 'HAPPEN', 'DEEP', 'STATES', 'OVERTURNS', 'DUELY', 'ELECTED', 'PRESIDENT', 'HERE', 'LIST', 'EVERY', 'SINGLE', 'TIME', 'OBAMA', 'COMMITTED', 'IMPEACHABLE', 'OFFENSE', 'THAT', 'DEMS', 'MEDIA', 'COVERED', 'MSNBC', 'MSNBC']
# ['AUSTRALIA', 'NISA']
# []
# []
# []
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON']
# []
# []
# ['ISIS', 'ISIS', 'LVMP']
# ['FILE', 'PHOTO', 'TODAY', 'FILE', 'PHOTO', 'TODAY', 'UCLA', 'ESPN', 'ESPN', 'UCLA', 'ESPN', 'ESPN', 'UCLA', 'UCLA']
# ['PAUL', 'RICHARDS', 'NATO', 'NATO']
# ['REUTERS', 'REUTERS']
# []
# ['CINCINNATI']
# ['UCLA', 'UCLA']
# []
# ['ESPN']
# ['VIEW', 'GALLERY', 'VIEW', 'GALLERY']
# ['REUTERS', 'REUTERS', 'SYDNEY']
# []
# []
# ['REUTERS', 'REUTERS', 'HOUSTON']
# []
# ['REUTERS', 'REUTERS', 'PARIS', 'IRAN', 'HEGEMONIC', 'TEMPTATIONS']
# []
# []
# ['REUTERS', 'REUTERS', 'BERLIN', 'DECISION']
# ["USA'", 'REUTERS', "USA'", 'REUTERS', 'DHABI']
# []
# []
# ['ISIS']
# []
# ['FILE', 'PHOTO', 'TODAY', 'FILE', 'PHOTO', 'TODAY', 'ESPN']
# ['CINCINNATI']
# ['REUTERS', 'REUTERS', 'TOKYO']
# ['NYPD']
# []
# ['NATO', 'JUST', 'WATCHED', 'MUST', 'WATCH', 'JUST', 'WATCHED', 'MUST', 'WATCH']
# []
# ['HENDERSON']
# []
# []
# ['BREAKING']
# []
# ['AIDS', 'AIDS', 'UNAIDS', 'AIDS', 'AIDS', 'AIDS', 'PEPFAR', 'AIDS', 'AIDS', 'AIDS', 'PEPFAR', 'AIDS', 'PEPFAR', 'UNAIDS', 'PEPFAR', 'AIDS', 'AIDS', 'UNAIDS', 'UNAIDS', 'PEPFAR']
# ['RELATED', 'DAILY']
# []
# ['REUTERS', 'REUTERS', 'OOSTKAMP']
# []
# []
# []
# ['FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN']
# ['HAIRY', 'NEWS', 'LGBT', 'LGBT']
# ['CONSERVATIVE', 'TRIBUNE']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# ['YMCA', 'SPAN']
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'AMZN', 'AVGO', 'MSCI', 'FCHI', 'GDAXI', 'IBEX', 'IBEX', 'MSCI', 'IXIC']
# []
# ['JUST', 'WATCHED', 'MUST', 'WATCH', "CNN'"]
# ['MEXICO', 'CITY']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'KUALA', 'LUMPUR']
# []
# ['POPE', 'HARRY', 'WALKER']
# []
# ['HUGE']
# ['PHOTO', 'REUTERS', 'JAMES', 'LAWLER', 'DUGGAN', 'ACLJ', 'ACLJ', 'ACLJ']
# []
# []
# []
# ['FILE', 'PHOTO', "NBC'", 'REUTERS', 'FILE', 'PHOTO', "NBC'", 'REUTERS', 'YORK', 'IGNITION', 'CMCSA']
# []
# []
# ['REUTERS', 'REUTERS', 'BEIRUT', 'OTHER', 'EVACUATIONS']
# []
# ['ASKING', 'THESE', 'QUESTIONS', 'HOURS', 'BEFORE', 'VOTE']
# ['FILE', 'PHOTO', 'KCNA', 'KCNA', 'REUTERS', 'FILE', 'PHOTO', 'KCNA', 'KCNA', 'REUTERS', 'SEOUL']
# []
# ['ANON', 'JEKLOY']
# []
# []
# ['REUTERS']
# ['REUTERS', 'REUTERS', 'MEXICO', 'CITY']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BOSTON']
# ['FLOTUS', 'FLOTUS']
# ['VEGAS']
# ['ARTIST', 'YEAR', 'ALBUM', 'YEAR', 'CONGRATULATIONS', 'WINNERS']
# ['NBCDFW']
# []
# ['ANON', 'JEKLOY']
# ['BREITBART', 'OLIVER', 'LANE']
# []
# []
# []
# []
# []
# []
# ['CIRCLE']
# []
# ['TRNC', 'REUTERS', 'TRNC', 'REUTERS', 'ANGELES']
# []
# ['TODAY', 'TODAY']
# []
# []
# ['REUTERS', 'REUTERS', 'SHANGHAI', 'PAYBACK', 'AFTER', 'PARTY', 'SHANGHAI', 'BEIJING']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON']
# ['REUTERS', 'REUTERS', 'FRANKFURT', 'PARIS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'HONG', 'KONG', 'MSCI']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'YORK', 'HMMJ', 'GWPRF']
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# []
# []
# []
# []
# []
# ['BALTIMORE', 'SCROLL', 'DOWN', 'CLICK', 'NEXT', 'PAGE', 'CONTINUE', 'READING']
# ['BREAKING', 'SHOCKING', 'AMAZING', 'READ', 'HERE']
# ['REUTERS', 'REUTERS', 'LONDON', 'MILAN', 'SRENH', 'STOXX', 'STOXX', 'GDAXI', 'FTSE', 'STOXX', 'FTSE', 'STOXX', 'MSCI', 'SRENH', 'STOXX', 'ANDR']
# []
# ['KYSP']
# []
# []
# ['CFPB']
# ['REUTERS', 'REUTERS', 'FRANCORCHAMPS']
# ['OPEC', 'OPEC']
# []
# ['AIDS', 'GMHC']
# []
# []
# ['REUTERS', 'REUTERS', 'LONDON', 'SLOWDOWN', 'AHEAD']
# []
# ['REUTERS', 'REUTERS', 'BAGHDAD', 'SHRINKING', 'CALIPHATE']
# []
# ['WARNING', 'ARTICLE', 'ABOVE', 'WORK', 'SATIRE', 'PLEASE', 'SHARE', 'RESPONSIBLY']
# []
# ['REUTERS', 'REUTERS', 'MUMBAI']
# ['RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS', 'RAMRANTS']
# ['CONFIRM', 'HIGH', 'RADIATION']
# ['REUTERS', 'REUTERS', 'ATHENS']
# []
# []
# []
# ['LAURA', 'INGALLS', 'WILDER', 'SPIRITUAL', 'ANARCHY', 'LOVED', 'LAURA', 'INGALLS', 'WILDER', 'SPIRITUAL', 'ANARCHY', 'ANARCHIST']
# ['TULSA']
# ["IT'S"]
# []
# ['REUTERS', 'REUTERS', 'ANGELES', 'MASH']
# []
# ['IPTV']
# ['REUTERS', 'REUTERS', 'YORK', 'FTSE', 'FTSE', 'STOXX', 'MSCI']
# []
# ['REUTERS', 'REUTERS', 'SEOUL', 'TSLA', 'IONIQ', 'HYDROGEN', 'TOKYO']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SYDNEY']
# ['NATO']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'JAKARTA', 'MYRX', 'MYRX']
# ['CHICAGO']
# ['REUTERS', 'REUTERS', 'OTTAWA']
# ['FILE', 'PHOTO', 'TIMA', 'REUTERS', 'FILE', 'PHOTO', 'TIMA', 'REUTERS', 'DUBAI']
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TORONTO']
# []
# ['REUTERS', 'REUTERS', 'LONDON', 'YOUTHFUL', 'BRIGADE']
# ['CHRISTOF', 'STACHE']
# ['REUTERS', 'REUTERS', 'YORK', 'USOILG', 'OPEC', 'OPEC', 'OPEC', 'CNPC']
# ['CAIRO']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ZURICH', 'LONDON']
# ['REUTERS', 'REUTERS', 'YORK']
# []
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'FOXA', 'SKYB']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'FRANKFURT', 'MSFT', 'CVSS']
# ['SUNY']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['MSNBC']
# []
# ['REUTERS', 'REUTERS', 'SYDNEY', 'AUSTRAC', 'AUSTRAC', 'SILVER', 'LININGS']
# ['CBGB']
# ["GOP'"]
# []
# []
# []
# ['FISA']
# []
# ['THIS', 'MORNING']
# ['AIDS', 'AIDS', 'AIDS', 'AIDS', 'AIDS', 'AIDS', 'AIDS']
# ['BWLD']
# []
# []
# []
# ['JUST']
# []
# ['REUTERS', 'REUTERS', 'PROCESS', 'DISCRETE', 'AUTOMATION', 'MAVERICK']
# ['UEFA', 'UEFA', 'ESPN']
# ["CNN'"]
# ['REUTERS', 'REUTERS', 'LONDON', 'LIKE', 'CALM', 'CECG', 'MEOG', 'FNAC']
# ['REUTERS', 'REUTERS', 'WASHINGTON']
# []
# ['LIGAS', 'EUROPEIAS', 'UEFA', 'COPAS', 'COPA', 'BRASIL', 'COPA', 'MUNDO', 'FIFA', 'COPA', 'MUNDO', 'TORNEIOS', 'AMERICANOS']
# ['SEBI', 'REUTERS', 'SEBI', 'REUTERS', 'MUMBAI', 'SEBI', 'SEBI', 'BFSI']
# ['REUTERS', 'REUTERS', 'WASHINGTON']
# ['AIDS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SYDNEY', 'BTSP', 'SEOUL', 'LONDON']
# []
# []
# ['REUTERS', 'REUTERS', 'GUANGZHOU', 'BEIJING', 'NSUG', 'TSLA']
# ['NORTH', 'LAWNDALE']
# []
# ['FESA', 'FESA']
# ['REUTERS', 'REUTERS', 'BRUSSELS', 'LONDON']
# []
# []
# []
# ['FLINT', 'MICHIGAN']
# ['TODAY', 'TODAY']
# []
# []
# ['NAFTA', 'NAFTA', 'NAFTA', 'UKIP', 'BILD', 'NATO']
# ['WNCN', 'WNCN', 'SHARE']
# []
# ['JUST', 'WATCHED', 'MUST', 'WATCH', "AFI'"]
# []
# ['RUSH', 'RUSH', 'RUSH', 'RUSH', 'CALLER', 'RUSH', 'RUSH', 'RUSH', 'RUSH']
# ['SOURCE', 'BREITBART']
# ['BUILD', 'WALL']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'PAULO', 'LOST', 'OPPORTUNITIES', 'FIES', 'FIES', 'FIES']
# ['REUTERS', 'REUTERS', 'TOKYO', 'METI', 'METI']
# []
# ['REUTERS', 'REUTERS']
# []
# []
# ['DARPA', 'USCENTCOM', 'DARPA', 'DARPA', 'ATTN', 'DARPA', 'DARPA', 'CDMA', 'SDSU', 'CLICK', 'HERE', 'STEVE', 'QUAYLE', 'CLICK', 'HERE', 'FIND', 'MORE', 'SIGN', 'HERE']
# ['CANNOT', 'ATTACK', 'DONALD', 'TRUMP', 'FAKE', 'NOTHING', 'ENTIRE', 'EXPOSE', 'REALLY', 'NOBODY', 'LIKES', 'HILLARY', 'NEVER', 'WILL']
# []
# ['ANKARA']
# []
# []
# ['REUTERS', 'REUTERS']
# ['LIVE', 'COVERAGE', 'WATE']
# []
# []
# ['UNITED', 'NATIONS', 'UNSC', 'UNSC']
# ['VIEW', 'GALLERY']
# ['CBGB']
# []
# ['LGBTQ', 'LGBTQ', 'LGBTQ', 'LGBTQ', 'CLAIRE', 'HEDDLES']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['FLYNN']
# []
# ['READ', 'MORE', 'REUTERS']
# []
# []
# []
# []
# []
# ['TODAY', 'TODAY']
# []
# ['VIEW', 'GALLERY']
# ['ARTIST', 'YEAR', 'ALBUM', 'YEAR', 'CONGRATULATIONS', 'WINNERS']
# ['UNGA', 'BRICS']
# []
# ['CCTV']
# ['REUTERS', 'REUTERS', 'FRANKFURT', 'BMWG']
# []
# ['GONE', 'WKYT', 'WKYT', 'PLEASE', 'SUBSCRIBE', 'YOUTUBE', 'CHANNEL', 'FORGET', 'LIKE']
# ['REUTERS', 'REUTERS', 'MOSCOW']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TOKYO']
# []
# ['KCNA', 'KCNA', 'KCNA', 'ICBM', 'KCNA', 'KCNA']
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SEOUL']
# ['REUTERS', 'REUTERS', 'SYDNEY']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'CLIFF', 'EDGE']
# []
# []
# []
# ['BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS']
# ['EXCLUSIVE', 'VIDEO', 'UNBELIEVABLE', 'VIRAL']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MADRID', 'THERE', 'ALTERNATIVE']
# ["NBC'"]
# []
# ['REUTERS', 'ATTENTION', 'EDITORS', 'THIS', 'IMAGE', 'PROVIDED', 'THIRD', 'PARTY', 'RESALES', 'ARCHIVE', 'AUSTRALIA', 'ZEALAND', 'REUTERS', 'ATTENTION', 'EDITORS', 'THIS', 'IMAGE', 'PROVIDED', 'THIRD', 'PARTY', 'RESALES', 'ARCHIVE', 'AUSTRALIA', 'ZEALAND', 'SYDNEY']
# ['REUTERS', 'REUTERS', 'SINGAPORE']
# []
# []
# ['FRANCISCO']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK']
# ['REUTERS', 'WASHINGTON', 'KENNEDY', 'PIVOTAL', 'JUSTICE']
# ['REUTERS', 'REUTERS', 'LONDON', 'MSCI', 'MSCIEF', 'JPMEGDR', 'BRLUSD', 'TRYUSD', 'ZARUSD', 'MSCI', 'STELLAR', 'GAINS', 'LIMITED', 'HOLDINGS', 'BAML', 'BAML', 'BAML']
# []
# []
# []
# ['EXCLUSIVE']
# ['LGBT', 'LGBT']
# ['LGBTQ']
# []
# []
# []
# []
# ['BUXX', 'USDJPY', 'EURUSD', 'GBPUSD', 'EURUSD', 'CIPS']
# []
# ['VIII', 'COINTELPRO']
# ['ISIS']
# ['KDVR']
# ['WATCH']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BERLIN', 'VDMA', 'VDMA']
# ['REUTERS', 'REUTERS', 'SHLD']
# ['CMCSA']
# []
# ['FINALLY', 'LESS']
# []
# []
# ['BREAKING']
# ['MORE', 'HERE']
# ['WASHINGTON']
# []
# ['FILE', 'PHOTO', 'MOES', 'REUTERS', 'FILE', 'PHOTO', 'MOES', 'REUTERS', 'KHOBAR']
# []
# ['VOICE', 'EUROPE']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BERLIN', 'INSA', 'DOMESTIC', 'DEMAND', 'EUROPE', 'ENGINE']
# ['WFAA']
# ['KRAFT', 'KRAFT', 'KRAFT', 'KRAFT', 'KRAFT', 'KRAFT']
# []
# ['VIDEO', 'VIDEO']
# []
# ['KYSP']
# []
# []
# []
# ['FACT', 'FACT', 'FACT']
# ['VIEW', 'GALLERY']
# []
# ['JUST', 'WATCHED', 'MUST', 'WATCH']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BERLIN', 'INSA']
# []
# []
# []
# ['JUST', 'WATCHED', 'MUST', 'WATCH', 'JUST', 'WATCHED', 'MUST', 'WATCH']
# ['SNAP', 'SNAP', 'JUST', 'WATCHED', 'MUST', 'WATCH', 'SNAP', 'SNAP', 'SNAP', 'SNAP', 'SNAP']
# []
# []
# []
# []
# []
# ['WAVY', 'WAVY', 'WAVY', 'WAVY']
# ['SHOCKING']
# []
# []
# ['FIFA', "CSKA'", 'CSKA', 'FIFA', 'READ', 'MORE']
# ['WATCH']
# []
# ['FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF', 'FFRF']
# []
# []
# ['PRISM', 'GVTC', 'OANN']
# []
# ['TODAY', 'TODAY', 'TORONTO']
# ['OPEC', 'OPEC', 'OPEC']
# []
# []
# ['ISIS']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'FRANKFURT']
# ['ISIS', 'ISIS', 'ISIS']
# []
# ['ESPN']
# []
# ['AQAP']
# ['UNESCO', 'RCEP', 'COSCO', 'MERICS', 'MERICS', 'MERICS', 'MERICS', 'MERICS', 'MERICS']
# []
# []
# ['FILE', 'PHOTO', "ANA'", 'REUTERS', 'FILE', 'PHOTO', "ANA'", 'REUTERS', 'TOKYO']
# ['WASHINGTON', 'COUNT', 'MICHAEL', 'FLYNN', 'FLYNN', 'FLYNN', 'FLYNN', 'FLYNN', 'FLYNN']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['REUTERS', 'REUTERS', 'WASHINGTON', 'LONDON', 'GLOBAL', 'DOMINANCE', 'QUESTION', 'CFTC', 'CFTC', 'REPO', 'COMPROMISE']
# []
# []
# ['DEVASTATING']
# []
# ['ANON', 'JEKLOY']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'CRITICAL', 'MOMENT', 'TAMOJL']
# []
# ['CREW', 'CREW']
# []
# ['WWII', 'WWII', 'WWII']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LIMA', 'PAULO', 'FIFA', 'FIFA', 'ESPN', 'FIFA', 'FIFA']
# []
# ['CHICAGO']
# ['ARTIST', 'YEAR', 'ALBUM', 'YEAR', 'CONGRATULATIONS', 'WINNERS']
# ['RUSH', 'RUSH', 'RUSH', 'RUSH', 'CALLER', 'RUSH', 'RUSH', 'RUSH', 'RUSH']
# []
# []
# []
# ['FILE', 'PHOTO', 'OPEC', 'REUTERS', 'FILE', 'PHOTO', 'OPEC', 'REUTERS', 'BEIRUT', 'CNPC']
# ['EDITOR', 'NOTE']
# []
# []
# []
# ['OBOR', 'COSCO']
# ['USDA', 'NOSB', 'USDA', 'USDA', 'USDA', 'USDA', 'USDA', 'USDA']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIJING', 'TRADE', 'FRICTIONS']
# ['REUTERS', 'REUTERS', 'LILLE']
# []
# []
# ['DONT', 'STOP', 'DONT', 'STOP', 'STOP']
# []
# ['UKSH']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIJING', 'DPRK', 'DPRK', 'KCNA']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'VALENCIA']
# []
# []
# []
# ['CREDO', 'CREDO']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ABUJA']
# []
# []
# ['REUTERS', 'REUTERS', 'FRANKFURT', 'IFRS', 'IFRS']
# ['ICBM', 'ICBM']
# ['SCROLL', 'DOWN', 'VIDEO', 'PUTTING', 'CAUSING']
# []
# []
# []
# ['PITI', 'PITI']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TORONTO', 'FRANCISCO']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'STOCKHOLM', 'NATO']
# ['MOSCOW', 'READ', 'MORE', 'DPRK', 'ICBM', 'READ', 'MORE']
# []
# []
# ['VIEW', 'GALLERY', 'NCAA']
# ['BEIJING', 'READ', 'MORE', 'READ', 'MORE']
# ['REUTERS', 'REUTERS', 'MOSUL', 'SHORTAGES', 'EVERYTHING']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['REUTERS', 'REUTERS', 'BEIJING']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# ['REUTERS', 'REUTERS', 'BERN']
# []
# ['TODAY']
# []
# ['REUTERS', 'REUTERS', 'NWSA', 'TRNC']
# ['FLOTUS', 'FLOTUS', 'POTUS']
# ['PRESIDENT', 'UNITED', 'STATES', 'DONALD', 'TRUMP', 'RETWEETED', 'THREE', 'DEPUTY', 'LEADER', 'JAYDA', "FRANSEN'S", 'TWITTER', 'VIDEOS', 'DONALD', 'TRUMP', 'HIMSELF', 'RETWEETED', 'THESE', 'VIDEOS', 'AROUND', 'MILLION', 'FOLLOWERS', 'BLESS', 'TRUMP', 'BLESS', 'AMERICA']
# ['REUTERS', 'REUTERS', 'CARACAS', 'PDVSA']
# []
# []
# ['SHARES', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ANOTHER']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BRUSSELS']
# []
# []
# []
# ['MORE', 'HERE']
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BANGKOK', 'PASSPORTS']
# []
# ['REUTERS', 'REUTERS', 'TEGUCIGALPA', 'ZELAYA', 'RETURNS']
# ['REUTERS', 'REUTERS', 'YORK', 'CALGARY', 'PHMSA', 'PHMSA']
# ['VIEW', 'GALLERY']
# ['REUTERS', 'REUTERS', 'BAGHDAD']
# []
# ['REUTERS', 'REUTERS', 'TUNIS', 'UTICA', 'UGTT', 'UGTT', 'UGTT']
# []
# []
# []
# []
# []
# ['JINPING', 'ICBM']
# ['REUTERS', 'REUTERS', 'USOPIN', 'NFIB', 'NFIB']
# []
# []
# []
# []
# []
# ['TUESDAY', 'PUZZLE', 'TURNS', 'PRINT', 'EVIDENCE', 'TELL', 'TURN', 'PRINCETON', 'SLASH', 'ETUDE', 'TRADE', 'ROUTES']
# []
# ['LGBTQ']
# []
# []
# []
# ['CNBC']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'BRUSSELS', 'DIVORCE', 'BILL']
# ['BREAKING']
# ['REUTERS', 'REUTERS', 'BERLIN']
# ['REUTERS', 'REUTERS', 'VIENNA', 'ANDR']
# []
# []
# ['NYPD', 'LGBTQ', 'LGBTQ', 'LGBTQ']
# ['BOSTON', 'ACLU', 'ACLU', 'MDMA', 'MDEA', 'ACLU', 'ACLU', 'ACLU', 'ACLU', 'ACLU', 'ACLU', 'ACLU', 'MDMA', 'MDEA', 'ACLU', 'ACLU', 'ACLU', 'ACLU', 'ACLU', 'ACLU']
# ['REUTERS', 'REUTERS']
# []
# ['SUMMARY', 'SUMMARY', 'SUMMARY', 'SUMMARY', 'SUMMARY', 'SUMMARY', 'SUMMARY', 'GABA', 'SUMMARY', 'GABA', 'SUMMARY', 'SUMMARY']
# ['REUTERS', 'REUTERS', 'BARCELONA']
# []
# ['REUTERS', 'REUTERS', 'BENGALURU', 'NAFTA', 'NAFTA', 'NAFTA', 'NAFTA']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON']
# ['ISIS', 'ISIS', 'FOTO', 'REUTERS', 'AHMED', 'JADALLAH', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS', 'ISIS']
# []
# ['DACA', 'DACA', 'DACA']
# []
# ['COPD', 'AARP', 'ABBA']
# ['BELLEFONTE']
# []
# ['REUTERS', 'REUTERS', 'PARIS', 'SOGN']
# []
# ['REUTERS', 'REUTERS', 'YORK', 'MSCI', 'MSCI', 'SLIDE', 'CONTINUES']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# []
# []
# []
# ['NATO', 'LONGER', 'SUSTAINABLE']
# []
# []
# ['REUTERS', 'REUTERS', 'ESPN']
# ['FILE', 'PHOTO', 'REUTERS', 'POOL', 'FILE', 'PHOTO', 'REUTERS', 'POOL', 'DAKAR']
# ['REUTERS', 'REUTERS', 'OTTAWA', 'NAFTA']
# []
# ['REUTERS', 'REUTERS', 'TRAVERSE', 'CITY']
# []
# []
# ['MARGARET', 'LYONS', 'PONIEWOZIK', 'LYONS', 'PONIEWOZIK', 'LYONS', 'PONIEWOZIK', 'LYONS']
# ['FOTO', 'REUTERS', 'AKHTAR', 'SOOMRO', 'CLAAS']
# []
# []
# ['REUTERS', 'REUTERS', 'TOKYO', 'BMWG']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'VDAN', 'CAIL', 'GLEN']
# ['BREAKING']
# ['SOMETHING', 'AMAZING', 'HAPPENED', 'CHURCH', 'WHEN', 'TRUMP', 'PRAYING', 'THING', 'SAVE', 'AMERICA', 'MIRACLE']
# ['TODAY', 'TODAY', 'MISSED', 'PUTTS', 'BEST', 'CHIP']
# ['REUTERS']
# ['OFFICIAL', 'JUST', 'PASSED']
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'BENGALURU', 'ASSET', 'WRAP', 'ASSET', 'ASSET', 'ASSET', 'ASSET']
# []
# []
# ['NYPD', 'NYPD', 'NYPD']
# []
# ['SILICON', 'VALLEY', 'SCROLL', 'DOWN', 'CLICK', 'NEXT', 'PAGE', 'CONTINUE', 'READING']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BERLIN']
# []
# ['CONFIRM', 'HIGH', 'RADIATION']
# ['BREAKING']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK', 'EURJPY', 'BTSP']
# ['RUSH', 'RUSH', 'RUSH', 'RUSH', 'CALLER', 'RUSH', 'RUSH', 'RUSH', 'RUSH']
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'JAKARTA', 'MAFINDO']
# ['TODAY', "ESPN'"]
# []
# []
# []
# ['GETTY', 'IMAGES', 'NORTH', 'AMERICA']
# ['PTSD']
# ["OSCE'"]
# []
# []
# ['REUTERS', 'REUTERS', 'JERUSALEM', 'BSGR', 'BSGR', 'BSGR']
# ['REUTERS', 'REUTERS', 'MEXICO', 'CITY', 'NAFTA', 'BRICS', 'NAFTA', 'NAFTA', 'BRICS', 'BABA']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TORONTO', 'OPEC', 'GSPTSE', 'OPEC']
# []
# ['STATS']
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'MCRN', 'OMERS', 'OMERS', 'OMERS', 'ONEX']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MADRID']
# ['CCTV']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# []
# ['TIBBO', 'DEDON']
# []
# []
# ['REUTERS', 'REUTERS', 'KIEV', 'NATO']
# []
# ['PTSD', 'RAINN']
# []
# []
# ['POTUS', 'INCREDIBLE', 'SHARE', 'PROUD', 'PRESIDENT', 'TRUMP', 'DOING', 'BEST', 'LEAD', 'AMERICA', 'BACK', 'GREATNESS']
# ['LONDON']
# []
# []
# []
# []
# ['ICBM', 'ICBM']
# ['WASHINGTON']
# ['FILE', 'PHOTO', 'OPEC', 'REUTERS', 'FILE', 'PHOTO', 'OPEC', 'REUTERS', 'DUBAI', 'LONDON', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'ALLIANCE', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# []
# []
# ['GFDL', 'PTSD']
# []
# ['LUCHA', 'LUCHA', 'LUCHA', 'LUCHA', 'LUCHA', 'LUCHA']
# []
# ['BACK', 'STUDY', 'COURSE', 'PHOTO', 'STUDY', 'GUIDE', 'RECOMMENDING', "MOORE'S", 'BOOK', 'PHOTO', 'FROM', 'COURSE', 'STUDY', 'GUIDE', 'PHOTO', 'STUDY', 'GUIDE']
# ['BANDY', 'HAVEN']
# []
# ['NASA', 'SUPERMOON', 'NASA', 'NASA', 'SCROLL', 'DOWN', 'VIDEO']
# []
# []
# ['TODAY', 'TODAY']
# ['PITTSBURGH', 'ESPN']
# ['VIEW', 'GALLERY', 'ABOARD', 'LANE', 'TRAIN', 'TAMU', 'BREAKING']
# ['SADC', 'REUTERS', 'SADC', 'REUTERS', 'JOHANNESBURG', 'ZUMA', 'FOCUS', 'CRIME', 'POLITICS', 'BUSINESS']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON']
# ['LGBT', 'LGBT', 'LGBT', 'LGBT', 'POTUS', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBT']
# ['HOLLAH']
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK']
# ['CITIC', 'RAND']
# ['REUTERS', 'REUTERS', 'SYDNEY']
# ['NEVER', 'BANNED', 'MOORE', 'ACCUSERS', 'HAVE', 'BEEN', 'DEBUNKED', 'PATHETIC', 'LIARS']
# ['WILL', 'SILENT', 'MUST', 'BAND', 'TOGETHER', 'RAISE', 'VOICES', 'SLAVE', 'TRADING']
# []
# []
# ['ALBANY', 'FREE', 'TRADE', 'DEALS', 'GUTTED', 'AFTER', 'NAFTA']
# []
# []
# ['REUTERS']
# ['REUTERS', 'REUTERS', 'KATHMANDU', 'BATTLE', 'INFLUENCE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SEOUL']
# ["CAIR'", 'CAIR']
# ['MORE', 'HERE']
# ['BILLION', 'CURE']
# []
# ['VIEW', 'GALLERY']
# ['SHAME']
# ['ULTA', 'AMZN', 'LVMH', 'DJIA']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BRATISLAVA']
# ['REUTERS', 'REUTERS', 'PARIS', 'CFDT', 'HSBC', 'HSBA', 'SOGN']
# []
# ['ANTI']
# []
# ['REUTERS', 'REUTERS', 'BEIJING']
# []
# ['REUTERS', 'REUTERS', 'BEIJING', 'SHANGHAI', 'CBRC', 'CBRC', 'CBRC', 'CBRC', 'CBRC', 'CBRC', 'NERVES', 'CBRC', 'CBRC', 'CBRC', 'CBRC', 'CBRC', 'ACGA']
# []
# ['REUTERS', 'REUTERS', 'GOTHENBURG']
# []
# []
# []
# ['ALLAH', 'WRONG', 'OUTRAGED']
# ['BPTU', 'ISIS']
# []
# ['MSNBC']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'JAKARTA', 'GOOGL']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON', 'CFPB']
# ['REUTERS', 'REUTERS', 'FRANKFURT']
# ["CNN'"]
# []
# []
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'MSCI', 'IXIC', 'MSCI', 'TAXING', 'TIMES', 'MSCI']
# ['LGBTQ']
# []
# ['CCTV']
# []
# ['READ', 'MORE']
# []
# []
# []
# ['CONAN', 'DESTROYER', 'DESTROYER', 'CONAN', 'TWENTY', 'BATTLESHIP', 'SUBMARINE', 'SANDWICH', 'CARRIER', 'PIGEON', 'BASTES', 'ARMING', 'DESTROYER', 'CRUISER', 'SUBMARINE', 'CARRIER', 'BATTLESHIP', 'JOHN', 'JUKEBOX', 'HERO', 'LOOSE', 'CANNON', 'LIKE', 'ROOMBA', 'CARRIER', 'PIGEON', 'SUBMARINE', 'SANDWICH', 'BOOR']
# ['CEDAR', 'PARK', 'WCHA', 'WCHA', 'WCHA', 'WCHA', 'WCHA', 'NCAA', 'WCHA', 'WCHA', 'NCAA', 'BCMML', 'KIJHL', 'BCHL', 'BCHL', 'BCHL']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON', 'LDOS', 'TALKING', 'POINT', 'NMCI']
# ['UWEX', 'COMBAT', 'TROOPS', 'MIAC', 'WWII', 'ICANN', 'USING', 'FEAR', 'CONTROLLING', 'PEOPLE', 'WILL', 'FIGHT']
# []
# []
# ['REUTERS', 'REUTERS', 'COPENHAGEN']
# []
# []
# []
# []
# []
# ['LONDON']
# ['TODAY', 'TODAY']
# []
# ['TODAY', 'TODAY']
# []
# []
# ['USHERALD']
# ['CATL', 'CATL', 'CATL', 'CATL', 'CATL', 'CATL', 'CATL', 'CATL']
# ['EVER', 'UPDATE']
# []
# ['PHILADELPHIA']
# ['TODAY', 'TODAY']
# []
# ['REUTERS', 'REUTERS', 'LONDON', 'WRETCHED', 'NIGHT']
# ['BREAKING']
# ['DACA', 'DACA', 'DACA']
# ['MOSCOW']
# ['JUMPING']
# []
# []
# ['REUTERS', 'REUTERS', 'BRUSSELS', 'MONEY', 'TROUBLE']
# ['BREAKING', 'NEWS']
# []
# ['TELL', 'CURSED', 'BREAK', 'SPELL', 'FROM', 'DEAD', 'SPIRIT']
# []
# ['REUTERS']
# []
# []
# []
# []
# ['CLICK', 'HERE', 'LIKE', 'DAILY', 'BUZZ', 'LIVE', 'FACEBOOK']
# []
# ['REUTERS', 'REUTERS', 'HARARE']
# []
# ['REUTERS', 'REUTERS', 'SHANGHAI', 'NDRC', 'NDRC', 'NDRC', 'CRRC', 'SHANGHAI']
# []
# []
# ['NASA', 'LIHEAP', 'AIDS', "FDA'"]
# ['REUTERS', 'REUTERS', 'GENEVA', 'UNICEF', 'UNICEF', 'UNICEF']
# ['FILE', 'PHOTO', 'CHINA', 'YUAN', 'REUTERS', 'FILE', 'PHOTO', 'CHINA', 'YUAN', 'REUTERS', 'JEDDAH', 'ICBC', 'ICBC']
# ['READER', 'SUBMITTED', 'NEWS', 'HIDDEN', 'WEALTH', 'NAFTA', 'GATT', 'ALREADY', 'CAFR']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'COPENHAGEN', 'BADI', 'CYBER', 'HANGOVER', 'EBITDA']
# []
# ['OVERNIGHT']
# []
# ['DISTURBING', 'DISTURBING']
# []
# ['ANON', 'JEKLOY']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'FRANKFURT']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'PRAGUE']
# []
# []
# ['JUST', 'KSAT']
# []
# []
# []
# ['THIS']
# []
# []
# ['JUST', 'WATCHED', 'MUST', 'WATCH', 'ARSA']
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BELGRADE', 'UNESCO', 'NATO', 'UNESCO']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['FOUR', 'FREE', 'TICKETS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK', 'TSLA', 'ALONG', 'RIDE', 'PGIM']
# ['APEC', 'APEC', 'REUTERS', 'APEC', 'APEC', 'REUTERS', 'DANANG', 'APEC']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'STRASBOURG', 'HUNG', 'PARLIAMENT']
# ['APPROVED', 'EVER', 'APPROVED', 'WITH', 'FEMALE', 'GUIDANCE', 'APPROVED', 'WATCH', 'UNDER', 'CIRCUMSTANCES', 'IMDB', 'IMDB']
# []
# []
# ['CNBC', 'VWAP']
# []
# []
# []
# []
# ['PICKLE', 'STEP', 'DOWN', 'IGNORANCE', 'MORALLY', 'BANKRUPT', 'DRUGS', 'TOGA', 'ETHICS', 'COMMITTEE']
# []
# []
# []
# ["CNN'"]
# []
# []
# ['FILE', 'PHOTO', 'TODAY', 'FILE', 'PHOTO', 'TODAY']
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# ['SHARES', 'BREAKING', 'HOME', 'NEWS', 'POLITICS', 'BREAKING', 'INFO', 'NEWS']
# []
# ['BREAKING']
# []
# ['MEXICO', 'CITY', 'SCROLL', 'DOWN', 'CLICK', 'NEXT', 'PAGE', 'CONTINUE', 'READING']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'FRANKFURT']
# []
# ['POLITICO']
# ['NOME', 'MOON', 'FULL', 'TONIGHT', 'MORE', 'SUZANNE', 'VEGA', 'ALBUMS', 'BERN']
# ["NBC'", "CBS'", "NPR'", 'VOICES']
# []
# ['DACA', 'DACA']
# ['REUTERS', 'REUTERS', 'FRANKFURT']
# ['REUTERS', 'REUTERS', 'BEIJING', 'CEBM']
# ['AHMAD', 'RUBAYE', 'REUTERS']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'SKYB', 'FOXA', 'NWSA', 'CNBC']
# ['YOUNGSTOWN']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK']
# ['REUTERS', 'REUTERS', 'MOSCOW']
# ['REUTERS', 'REUTERS', 'DUBAI']
# ['REUTERS', 'REUTERS', 'WASHINGTON']
# []
# ['BRICS', 'MOSCOW', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS']
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'LONDON']
# ['POLITICO', 'MASSIVE', 'EVERYONE', 'BENCH', 'UPDATE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# []
# ['ISLAMABAD']
# []
# ['REUTERS', 'REUTERS', 'LONDON', 'SCOR', 'SCOR', 'EMEA']
# ['REUTERS', 'REUTERS', 'PARIS']
# ['REUTERS', 'REUTERS', 'MAIN', 'STREET', 'BANKER', 'LEADERSHIP', 'EFFORT']
# []
# []
# ['REUTERS', 'REUTERS', 'BRASILIA']
# ['NORTH', 'ATLANTIC', 'OCEAN']
# []
# ["TNC'"]
# ['VERY']
# ['REUTERS', 'REUTERS', 'WASHINGTON', 'USTR']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'FRANKFURT', 'VTOL']
# []
# []
# ['LGBT', 'LGBTQ', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBTQAI']
# []
# ["CNN'"]
# []
# ['MAGA']
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'SPLRCU', 'SPLRCS', 'IXIC', 'QCOM', 'AVGO', 'ROKU', 'NYSE']
# []
# []
# ['LGBT', 'LGBT', 'LGBT', 'LGBT', 'AARP', 'AARP', 'AARP', 'LGBT', 'LGBT', 'SAGE', 'LGBT', 'AARP', 'LGBT', 'LGBT', 'SAGE', 'SAGE', 'LGBT', 'SAGE', 'LGBT', 'LGBT', 'LGBT', 'LGBT', 'MICHAEL', 'ADAMS', 'SAGE', 'LGBT']
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'FILE', 'PHOTO', 'BELEK', 'RYDER']
# []
# ['CHARM', 'GOLDFINCHES', 'FLORA', 'MIDDLE', 'EARTH', 'AERIAL', 'GEOLOGY', 'GREAT', 'HIKING', 'TRAILS', 'WORLD', 'LIVING', 'FOREST', 'TREES', 'NORTH', 'AMERICA', 'ENIGMA', 'APPLES', 'PRICK', 'PRIVATE', 'GARDENS', 'AREA', 'FINE', 'PAPER', 'FLOWERS']
# ['REUTERS', 'REUTERS', 'WASHINGTON']
# []
# []
# []
# []
# []
# ['CSUN', 'CSUN']
# ['ICITE', 'ICITE']
# ['REUTERS', 'REUTERS', 'HELSINKI']
# ['CODEPINK']
# []
# []
# ['READ', 'MORE', 'FISA', 'READ', 'MORE']
# ['TUTORIAL']
# ['APOEL']
# ['REUTERS', 'REUTERS', 'BERLIN', 'NATO', 'OCCAR']
# []
# ['STAB', 'BACK', 'INHUMANELY']
# ['DACA', 'KCKQ']
# []
# []
# ['NAZI']
# ['TWTR']
# ['SBVC']
# []
# ['SELFIES']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BRUSSELS']
# ['ADAMS', 'ISNA']
# ['LOOK']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SEOUL']
# []
# []
# ['MORE', 'HERE']
# []
# []
# []
# []
# ['SOURCE']
# []
# []
# ['BREAKING']
# []
# []
# ['REUTERS', 'REUTERS', 'MAREA', 'BEIRUT', 'INFORMANTS', 'HEAVEN', 'FREEDOM']
# ['PHOTO', 'PIXABAY']
# ['NOTE']
# ['CCTV']
# ['KABC']
# ['ESPN', 'ESPN', 'ESPN']
# ['REUTERS', 'REUTERS']
# ['TODAY', 'TODAY', 'VEGAS', 'OPENINGS']
# ['SAMPLE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'HONG', 'KONG', 'STOCK', 'SURGES', 'PERCENT']
# ["CNN'"]
# ['VIDEO']
# ['REUTERS', 'REUTERS', 'YORK', 'DOLLAR']
# ['ITEP', 'ITEP']
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'SPLRCM', 'IXIC', 'CSCO', 'NYSE']
# ['AIDS']
# ['BUND', 'BUND', 'BUND', "RWE'"]
# ['REUTERS', 'REUTERS', 'FREETOWN', 'FEAR', 'DISEASE']
# []
# ['LVMPD']
# []
# []
# ['TRUMP', 'TOWER']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON']
# ['FILE', 'PHOTO', 'WADA', 'WADA', 'REUTERS', 'FILE', 'PHOTO', 'WADA', 'WADA', 'REUTERS', 'WADA', 'WADA', 'WADA', 'WADA', 'RUSADA', 'INTELLIGENCE', 'WADA', 'RUSADA', 'WADA', 'WADA']
# ['FRESNO', 'MIGHT']
# []
# ['BREAKING', 'FUMING']
# ['REUTERS', 'REUTERS', 'NAIROBI', 'ISIL']
# ['ARTIST', 'YEAR', 'ALBUM', 'YEAR', 'CONGRATULATIONS', 'WINNERS']
# []
# ['SHARES', 'NEWS', 'POLITICS', 'WORLD', 'NEWS', 'INFO', 'NEWS']
# ['REUTERS', 'REUTERS', 'BEIJING', 'CBRC']
# ['HUDWAY', 'BRICS', 'HUDWAY', 'BRICS', 'HUDWAY', 'HUDWAY', 'HUDWAY', 'BRICS', 'HUDWAY', "HUDWAY'", 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRIC', 'BRIC', 'BRICS']
# []
# ['WASHINGTON']
# ['EVER', 'DONATE']
# ['REUTERS', 'REUTERS', 'BEIJING', 'SHANGHAI', 'SPECIAL', 'INVESTIGATION', 'SECTOR', 'BEIJING', 'SHANGHAI', 'BEIJING', 'BENGALURU', 'HONG', 'KONG']
# ['REUTERS', 'REUTERS', 'PARIS']
# []
# []
# ['LGBTQA']
# ['NORTH']
# []
# ['NYDN']
# ['ESRB']
# ['ROBERT', 'SPENCER']
# []
# []
# []
# ['WWII', "JFK'"]
# ['YORK']
# []
# ['BREAKING']
# ['SEPARATE', 'BABIES', "CNN'"]
# ['MERRY', 'CHRISTMAS', 'YEAR', 'LONG', 'MERRY', 'CHRISTMAS']
# ['REUTERS', 'REUTERS', 'MEXICO', 'CITY']
# ['CARSTEN', 'KOALL']
# []
# ['EXCLUSIVE']
# []
# ['REUTERS', 'REUTERS', 'FRANKFURT']
# []
# []
# ['UPDATE']
# ['REUTERS', 'REUTERS', 'AMZN', 'NOOK']
# ['REUTERS', 'REUTERS', 'LONDON', 'DELEVERAGING', 'DISCOMFORT', 'SSEC', 'CHINEXTP', 'POWER', 'JUNK', 'YARD', 'EPFR', 'SHIFTING', 'SANDS', 'CURVE', 'CONTROL']
# ['REUTERS', 'REUTERS', 'WASHINGTON', 'CONUNDRUM']
# ['ARGENTINA', 'WORLD', 'LGBT', 'LGBT']
# []
# ['RUSH', 'RUSH', 'RUSH', 'RUSH', 'CALLER', 'RUSH', 'RUSH', 'RUSH', 'RUSH']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'DELHI', 'GUWAHATI']
# []
# []
# []
# ['NATO', 'NATO']
# ['WASHINGTON']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'IRSG', 'IRSG', 'IRSG', 'DIFFICULT', 'LIFT']
# ['READ', 'MORE', 'ZUNDE', 'ARMY']
# ['BEAUTIFUL', 'ANIMALS', 'BOOK', 'JOAN', 'WINTER', 'CHANGELING', 'CHRISTMAS', 'DAYS', 'DANCE', 'JAKARANDA', 'DARK', 'FLOOD', 'RISES', 'DINNER', 'PARTY', 'ESSEX', 'SERPENT', 'EXIT', 'WEST', 'FAST', 'FIVE', 'CARAT', 'SOUL', 'FOREST', 'DARK', 'FRESH', 'COMPLAINT', 'FUTURE', 'HOME', 'LIVING', 'GIVING', 'GODHEAD', 'HISTORY', 'WOLVES', 'HOME', 'FIRE', 'HOMESICK', 'ANOTHER', 'WORLD', 'HORSE', 'WALKS', 'INTO', 'IDIOT', 'WILL', 'KIND', 'FREEDOM', 'LESS', 'LINCOLN', 'BARDO', 'MANHATTAN', 'BEACH', 'OSMOND', 'ABSOLUTE', 'DARLING', 'PEOPLE', 'NINTH', 'HOUR', 'PACHINKO', 'POWER', 'REFUGEES', 'SELECTION', 'SEPARATION', 'SING', 'UNBURIED', 'SING', 'FOUR', 'STAY', 'WITH', 'STONE', 'TIES', 'TRANSIT', 'WAKING', 'LIONS', 'WHEREAS', 'WHITE', 'TEARS', 'RICH', 'ANGER', 'AMERICAN', 'FIRE', 'ANIMALS', 'STRIKE', 'CURIOUS', 'POSES', 'BLOOD', 'EMMETT', 'TILL', 'BORN', 'CRIME', 'BUNK', 'CHURCHILL', 'ORWELL', 'COLLECTED', 'ESSAYS', 'ELIZABETH', 'HARDWICK', 'COLONY', 'NATION', 'COLOR', 'CRISIS', 'MIDDLE', 'CLASS', 'CONSTITUTION', 'DAWN', 'WATCH', 'DEATH', 'LIFE', 'GREAT', 'LAKES', 'DESTINED', 'DEVIL', 'BARGAIN', 'EVANGELICALS', 'EVOLUTION', 'BEAUTY', 'FASTING', 'FEASTING', 'FRIENDS', 'DIVIDED', 'FUTURE', 'HISTORY', 'GENERATION', 'REVOLUTION', 'GLASS', 'UNIVERSE', 'GRANT', 'GREATER', 'GOTHAM', 'GULF', 'HAMLET', 'GLOBE', 'GLOBE', 'HENRY', 'DAVID', 'THOREAU', 'HOUSE', 'GOVERNMENT', 'INVENTION', 'ANGELA', 'CARTER', 'JANESVILLE', 'KILLERS', 'FLOWER', 'MOON', 'KRAZY', 'LENIN', 'LETTERMAN', 'LOCKING', 'LOOKING', 'STRANGER', 'LOST', 'CITY', 'MONKEY', 'NOMADLAND', 'NOTES', 'FOREIGN', 'COUNTRY', 'PRAIRIE', 'FIRES', 'PRIESTDADDY', 'SONGS', 'KNOW', 'BEST', 'TENEMENTS', 'TOWERS', 'TRASH', 'SIRI', 'WITH', 'LOVE', 'UNDOING', 'PROJECT', 'WERE', 'EIGHT', 'YEARS', 'POWER', 'WHAT', 'HAPPENED', 'WORLD', 'WITHOUT', 'MIND', 'BRICK']
# ['REUTERS', 'REUTERS', 'VIENNA', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'GRADUAL', 'OUTPUT', 'BOOST', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# ['POLITICO']
# ['FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN', 'FPRN']
# []
# []
# ['OPEC', 'OPEC', 'VIENNA', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'JMMC', 'OPEC', 'OPEC', 'JMMC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# []
# ['REUTERS', 'REUTERS', 'MADRID', 'SECESSIONISTS', 'ODDS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MADRID', 'FROB']
# ['LONDON']
# []
# []
# ['REUTERS', 'REUTERS', 'TOKYO']
# ["FCC'"]
# ['PDVSA', 'REUTERS', 'PDVSA', 'REUTERS', 'CARACAS', 'YORK', 'PDVSA', 'ISDA', 'PDVSA', 'PDVSA', 'PDVSA', 'ISDA', 'ISDA', 'PDVSA', 'ISDA', 'ISDA', 'PDVSA', 'PDVSA', 'PDVSA', 'PDVSA']
# []
# ['DACA']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SHANGHAI']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TOKYO', 'CGPI', 'CGPI', 'CGPI']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TOKYO', 'DEFLATION', 'ESCAPE', 'NEARS']
# ['REUTERS', 'REUTERS', 'EBAY', 'AMZN']
# ['CAIR', 'CAIR', 'DFEH', 'CAIR', 'CAIR']
# ['PTSD', 'SAMPLE']
# []
# []
# ['DETAILS', 'WCCB']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ANGELES']
# []
# []
# ['REUTERS', 'REUTERS', 'ABIDJAN']
# []
# ['DETAILS', 'FOLLOW']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON']
# []
# ['YOUR', 'REALLY']
# ['WATE']
# ['REUTERS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIJING']
# []
# []
# []
# ['SPAN', "GOP'"]
# []
# ["NSA'", 'REUTERS', 'ODDJOB', 'FUZZBUNCH', 'ETERNALBLUE', 'DOUBLEPULSAR', "NSA'", 'ETERNALBLUE', 'DOUBLEPULSAR']
# []
# []
# ['HBO,', 'REUTERS', 'HBO,', 'REUTERS']
# ['REUTERS', 'REUTERS', 'SANTIAGO']
# ['NASA', 'NASA', 'NASA', 'NASA']
# []
# ['REUTERS', 'REUTERS', 'BANGKOK']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'OSAKA']
# []
# ['CHARLESTON', 'SEIU']
# ['ICTY', 'REUTERS', 'ICTY', 'REUTERS', 'HAGUE', 'ICTY', 'ICTY', 'GREATER', 'SERBIA', 'ICTY', 'ICTY', 'RESPECT', 'VICTIMS', 'LOOK', 'FUTURE', 'SERBIA', 'SREBRENICA', 'SLAUGHTER', 'ICMP', 'ICMP', 'ICTY', 'ICTY']
# ['APEC', 'REUTERS', 'APEC', 'REUTERS', 'SYDNEY', 'LURCH', 'RIGHT', 'SYDNEY']
# ['GABI', 'CNBC', 'GABI', 'CNBC', 'CNBC']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'CNBC', 'CNBC']
# ['LGBT', 'LGBT']
# []
# []
# ['PROVIDENCE', 'ISIS']
# []
# []
# []
# ['COLLUSION', 'CAPS']
# ['REUTERS', 'REUTERS', 'SINGAPORE', 'UBER', 'OVER', 'CAPITALIZED', 'MARKET', 'EXECUTIVE', 'CHURN', 'SINGAPORE', 'FRANCISCO', 'TOKYO']
# []
# []
# ['RTNB']
# ['FILE', 'PHOTO', 'TODAY', 'FILE', 'PHOTO', 'TODAY', 'DUBLIN', 'SPARTAN', 'CONDITIONS']
# ['BREAKING']
# []
# ['REUTERS', 'REUTERS', 'WASHINGTON', 'CRUCIAL', 'ELEMENT', 'OBAMACARE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MILAN', 'CBOE', 'CBOE']
# ['ISIS', 'ISIS', 'ISIS']
# ['NOAA']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'AYADIYA', 'BAGHDAD', 'CALIPHATE', 'RUINS']
# ['DEAL', 'PROPERLY', 'DEAL', 'FROM', 'POSITION', 'POWER', 'ABSOLUTE', 'BEST', 'REMEMBER', 'DEMAND', 'LIFE', 'EXTENSION', 'CLAUSE']
# ['REUTERS', 'REUTERS', 'ZURICH']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'DELHI']
# ['VIEW', 'GALLERY', 'NCAA']
# ['REUTERS', 'REUTERS', 'MIXED', 'RESULTS', 'MIXED', 'MOTIVATIONS']
# []
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# ['AMERICA', 'HERE', 'BBCA']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'HONG', 'KONG', 'BABA', 'BIDU', 'GAME', 'CHANGER', 'SASAHW', 'CNPOW', 'SASACN', 'GLPL']
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MAIDUGURI']
# []
# ['BREAKING', 'NEWS']
# []
# ['TRENDING', 'RELATED']
# ['WFAA']
# []
# []
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'SINGAPORE']
# []
# []
# []
# ['REUTERS', 'UNICEF']
# ["GOP'"]
# ['REUTERS', 'REUTERS', 'ATHENS']
# []
# []
# ['KISS']
# []
# ['ANGELES']
# []
# ['VIEW', 'GALLERY']
# []
# ['REUTERS', 'REUTERS', 'BEIRUT', 'ISNA', 'ILNA']
# []
# ['NASA']
# ...
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MOSCOW', 'LIST', 'OLIGARCHS', 'BANK', 'CHECKS']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'KABUL', 'NATO', 'CAIRO']
# []
# ['REUTERS', 'REUTERS', 'JERUSALEM']
# ['CNBC', 'VWAP']
# []
# ['REUTERS', 'REUTERS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BAGHDAD', 'LANDMINES', 'BOMBS']
# ['VATICAN', 'CITY']
# ['NYPD', 'NYPD', 'NYPD']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'YORK', 'LONDON']
# []
# ['VRCC', 'CLICK', 'HERE', 'LIKE', 'DAILY', 'BUZZ', 'LIVE', 'FACEBOOK']
# []
# ['NASA', 'NASA', 'NASA']
# []
# ['FIVE']
# ['JUST', 'WATCHED', 'MUST', 'WATCH', "CNN'", 'JUST', 'WATCHED', 'MUST', 'WATCH']
# []
# ['REUTERS', 'REUTERS', 'BRUSSELS', 'CAAT', 'GRADUAL', 'FLEXIBLE', 'SANCTIONS']
# []
# ['ANZEC', 'QUAD', 'QUAD', 'QUAD']
# []
# []
# ['ISIS']
# []
# ['REUTERS', 'REUTERS', 'BAGHDAD']
# ['DINK']
# ['ISIS', 'ISIS', 'ISIS', 'ISIS']
# []
# ['YORK']
# []
# []
# ['CLICK', 'HERE', 'LIKE', 'DAILY', 'BUZZ', 'LIVE', 'FACEBOOK']
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'SANA', 'SANA', 'REUTERS', 'FILE', 'PHOTO', 'SANA', 'SANA', 'REUTERS', 'AMMAN', 'RETURN', 'NORMALCY']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['READ', 'MORE', 'REUTERS']
# []
# []
# []
# []
# ['REUTERS']
# ['REUTERS', 'REUTERS', 'DENPASAR', 'VACC', 'VACC', 'AVIATION', 'WARNING', 'VONA', 'JAKARTA', 'SYDNEY']
# ['REUTERS', 'REUTERS', 'HYDERABAD', 'BILLBOARDS', 'MSFT']
# []
# ['REUTERS', 'READ', 'MORE']
# ['HERE', 'WHAT', 'WILL', 'HAPPEN', 'DEEP', 'STATE', 'TAKES', 'DOWN', 'PRESIDENT', 'TRUMP', 'PRETTY', 'THEM', 'ELDER', 'PATRIOT', 'EDITORS', 'NOTE', 'THIS', 'CALL', 'ARMS', 'RATHER', 'ANALYSIS', 'WHAT', 'WOULD', 'HAPPEN', 'DEEP', 'STATES', 'OVERTURNS', 'DUELY', 'ELECTED', 'PRESIDENT', 'HERE', 'LIST', 'EVERY', 'SINGLE', 'TIME', 'OBAMA', 'COMMITTED', 'IMPEACHABLE', 'OFFENSE', 'THAT', 'DEMS', 'MEDIA', 'COVERED', 'MSNBC', 'MSNBC']
# ['MEDIA', 'ADVISORYWHAT', 'WHERE', 'OKWHO', "ELD'S"]
# []
# ['READ', 'MORE']
# []
# ['NOTHING', "TWP'", 'HOLOCAUST', 'JUST', 'LIKE', "TWP'", 'ACTUALLY', 'DUNNO', 'CIVIL', 'RIGHTS', 'ORGANIZATIONS']
# ['REUTERS', 'REUTERS', 'DETROIT', 'UBER', 'UBER', 'AUTONOMOUS', 'PIZZA', 'DELIVERY', 'TSLA', 'BMWG', 'INTC', 'DLPH', 'FCHA']
# ['LGBT', 'LGBT', 'LGBT', 'LGBT', 'LGBT']
# []
# ["CNN'"]
# []
# []
# []
# []
# []
# ['JINPING', 'JINPING', "CNN'"]
# ['WARS', 'PLEASE', 'SUBSCRIBE', 'YOUTUBE', 'CHANNEL', 'FORGET', 'LIKE']
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'NAIROBI', 'ADAK', 'ADAK', 'WADA']
# []
# ['CNBC', 'VWAP']
# ['EPIC', 'EPIC', 'EPIC']
# ['PERFECT']
# ["GOP'"]
# ['REUTERS', 'REUTERS', 'WASHINGTON']
# []
# []
# []
# ['YURI', 'KADOBNOV']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'BUENOS', 'AIRES']
# ['NATO', 'NATO', 'NATO', 'NATO']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ZURICH', 'SRENH']
# ['UNDP', 'UNDP', 'UNDP', 'CCAF', 'CCAF', 'CCAF', 'CCAF', 'CCAF', 'UNDP', 'LDCF', 'LDCF', 'UNDP', 'CCAF']
# ['REUTERS', 'REUTERS', 'LONDON']
# ['ESPN']
# ['JRPG']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'WASHINGTON', 'EXIM', 'EXIM', 'EXIM', 'EXIM', 'EXIM', 'EXIM', 'EXIM']
# []
# ['CHICAGO', 'MANILA', 'MANILA']
# ['OPEC', "OPEC'", 'REUTERS', 'OPEC', "OPEC'", 'REUTERS', 'LONDON', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'DEMAND', 'BOOST', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# []
# ['STILL', 'PLEASE', 'SUBSCRIBE', 'YOUTUBE', 'CHANNEL', 'FORGET', 'LIKE']
# ['REUTERS', 'REUTERS', 'DHABI']
# ['UPDATE']
# ['REUTERS', 'REUTERS', 'CAIRO']
# ['NDAA', 'MISO']
# []
# []
# ['REUTERS', 'REUTERS', 'EDINBURGH']
# ['ICBM']
# ['BEER', 'BEER', 'BEER', 'BEER', 'BEER', 'BEER', 'BEER']
# []
# []
# []
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'NWSA', 'NVDA', 'ROKU', 'PRGO', 'DISH']
# []
# []
# ["FBI'", 'LGBT']
# []
# []
# ['TODAY']
# ['SCROLL', 'DOWN', 'VIDEO', 'CCTV']
# ['FALL', 'RIVER']
# []
# []
# ['JUST', 'WATCHED', 'MUST', 'WATCH']
# ['YORK']
# ['CEEC', 'REUTERS', 'CEEC', 'REUTERS', 'BUDAPEST']
# []
# ['OPEC', 'REUTERS', 'OPEC', 'REUTERS', 'LONDON', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# []
# []
# []
# []
# []
# ["NYU'"]
# ['KOMO', 'KUNS', 'KOMO', 'KOMO', 'KCPQ', 'KZJO', 'KOMO', 'KCPQ', 'KOMO', 'KOMO', 'KDNL', 'KTVI', 'KPLR', 'KDNL', 'KTVI', 'KOKH', 'KOCB', 'KOKH', 'KOCB', 'KOKH', 'KFOR', 'KAUT', 'KFOR', 'KOKH', 'KFOR', 'KJZZ', 'KUTV', 'KMYU', 'KENV', 'KENV', 'KENV', 'KRNV', 'KSNV', 'KSTU', 'KUTV', 'KSTU', 'KENV', 'KSNV', 'KVCW', 'KRXI', 'KRNV', 'KAME', 'KENV', 'KRNV', 'WBFF', 'WJLA', 'WJLA', 'WDCW', 'WJLA', 'WDCW', 'WRLH', 'WTVR', 'WRLH', 'WTVR', 'KRCR', 'KCVU', 'KUCO', 'KRVU', 'KAEF', 'KBVU', 'KECA', 'KEUV', 'KRCR', 'KAEF', 'KAEF', 'KRCR', 'KATU', 'KUNP', 'KRCW', 'KATU', 'KRCW', 'WPMT', 'WPMT', 'KDSM', 'KDSM', 'WWMT', 'WXMI', 'WWMT', 'WXMI', 'WXLV', 'WMYV', 'WMYV', 'WGHP', 'WXLV', 'WGHP', 'KECI', 'KCFW', 'KTVM', 'WGNO', 'WNOL', 'NOLA', 'WTIC', 'WCCT', 'KDAF', 'KDVR', 'KWGN', 'KIAH', 'WXIN', 'WTTV', 'WDAF', 'KTLA', 'WREG', 'WSFL', 'WPIX', 'WPHL', 'KTXL', 'KSWB']
# ['GFDL']
# ['RAISSMAN']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ZURICH', 'BOARD', 'SEAT']
# ['AARP', 'AARP']
# []
# []
# []
# []
# ['RUSH', 'RUSH', 'RUSH', 'RUSH', 'CALLER', 'RUSH', 'RUSH', 'RUSH', 'RUSH']
# ['LATEST']
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'LONDON', 'TRUMP', 'TOUR', 'EXCLUSIVE', 'BALLISTIC', 'BITCOIN', 'NEED', 'JOLT', 'JOLT', 'USJOLT', 'JOLTS', 'JOLTS', 'ITALIAN', 'BANKS', 'CRDI', 'BAMI', 'BMPS', 'VENEZUELA', 'RESTRUCTURING', 'OPEC', 'JOLTS']
# ['REUTERS', 'REUTERS', 'MILAN', 'LONDON', 'STOXX', 'STOXX', 'FTSE', 'FTSE', 'GDAXI', 'SXAP', 'STOXX', 'STOXX', 'IBES', 'MSCI', 'MSCI', 'OMVV', 'LXSG', 'ATCA', 'SGREN']
# ['EARLSBORO']
# []
# ['HIGHEST']
# ['MUST', 'NEVER', 'SWORN', 'DELAY', 'INAGURATION', 'INVESTIGATE', 'ARREST', 'ROSIE', 'DONALD', 'TRUMP', 'MENTALLY', 'UNSTABLE', 'LESS', 'THAN', 'WEEKS', 'STOP', 'AMERICA', 'AUTISM', 'NEVER', 'LEAVING', 'WILL', 'NEVER', 'PRESIDENT', 'MORON', 'USHERALD']
# []
# ['NASA', 'NATO']
# []
# []
# []
# ['HOLLYWOOD']
# []
# ['CONFIRMED', 'HIGH', 'RADIATION', 'RELEASED', 'AFTER', 'HANFORD', 'TUNNEL', 'COLLAPSE', 'CONFIRM', 'HIGH', 'RADIATION']
# ['JUST', 'WATCHED', 'MUST', 'WATCH']
# ['REUTERS', 'REUTERS', 'JERUSALEM', 'LINES']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON']
# ['REUTERS', 'REUTERS', 'YORK', 'ANGELES', 'AMZN', 'GOOGL', 'TALKS', 'STALL', 'AAPL', 'FOXA', 'VIAB', 'DISCA']
# []
# []
# ['REUTERS', 'REUTERS', 'QCOM', 'AVGO', 'AAPL', 'NXPI']
# ['REUTERS', 'REUTERS', 'VENICE']
# ['EBACE', 'REUTERS', 'EBACE', 'REUTERS', 'DUBAI', 'HEMS']
# []
# ['REUTERS', 'REUTERS', 'DHABI', 'VETTEL', 'THIRD']
# ['CFYC', 'CFYC']
# []
# []
# []
# []
# ['FIFA', 'IRIB']
# []
# []
# ['BILL', 'CLEARS', 'SENATE']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SCHLEIZ']
# ["CNN'"]
# ['UNICEF', 'REUTERS', 'UNICEF', 'REUTERS', 'NAYPYITAW', 'UNHCR', 'HORRENDOUS', 'ATROCITIES', 'YANGON', 'DHAKA', 'BAZAR']
# []
# []
# ['SCROLL', 'DOWN', 'VIDEO']
# ['BRICS', 'MOSCOW', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS']
# ['REUTERS', 'REUTERS', 'BOSTON']
# []
# ['READ', 'MORE']
# []
# []
# ['HAVE']
# ['REUTERS', 'REUTERS', 'BRUSSELS', 'CHERRY', 'PICKING']
# ['REUTERS', 'REUTERS', 'MADRID']
# ['REUTERS', 'REUTERS', 'BEIJING', 'SHKF', 'CEBM']
# []
# []
# ['REUTERS', 'REUTERS', 'UDEID', 'BASE', 'DIVIDING', 'LINE', 'DOWN', 'EUPHRATES']
# ['WRAL', 'READ', 'MORE', 'MORE', 'HERE']
# []
# ['DKNY', 'JUST', 'WATCHED', 'MUST', 'WATCH']
# ['SEIU', 'SEIU']
# ['REUTERS', 'REUTERS', 'SINGAPORE', 'SIAL', 'CAPA']
# []
# ['RIGHT', 'SHARE', 'THIS', 'EVERYWHERE', 'AGREE']
# []
# ['WASHINGTON']
# ['AIDS', 'AIDS', "ONE'", 'AIDS', 'AIDS', 'PEPFAR', 'PEPFAR', 'AIDS', 'AIDS', 'AIDS', 'PEPFAR', 'AIDS', 'PEPFAR', 'AIDS', 'AIDS', 'AIDS', 'PEPFAR', 'JUST', 'WATCHED', 'MUST', 'WATCH', 'PEPFAR', 'PEPFAR', 'AIDS', 'AIDS', 'AIDS', 'PEPFAR', 'PEPFAR', 'AIDS', 'AIDS']
# []
# []
# ['ALSO', 'ALSO', 'PHOTOS', 'ALSO', 'LADIES', 'ALSO', 'PHOTOS']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ANKARA']
# ['TODAY', 'TODAY', 'CHARLOTTE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TOKYO']
# ['MVCI']
# []
# ['KAJO', 'PERS', 'PERS']
# []
# []
# []
# ['HBCU']
# []
# []
# ['TODAY', 'TODAY']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'ZURICH']
# ['REUTERS', 'REUTERS', 'WASHINGTON', 'FSOC', 'FSOC', 'FSOC', 'FSOC', 'FSOC', 'FSOC', 'FSOC', 'FSOC', 'FSOC']
# ['REUTERS', 'REUTERS', 'GENEVA']
# ['REUTERS', 'REUTERS', 'YORK', 'CNBC', 'CNBC', 'CNBC']
# []
# []
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIJING', 'PRICE', 'BOOST']
# ['NORTH', 'KOREA', 'SCROLL', 'DOWN', 'CLICK', 'NEXT', 'PAGE', 'CONTINUE', 'READING']
# []
# []
# ['BELLEFONTE']
# []
# ['HELL', 'THINK', 'REALLY']
# []
# ['WASHINGTON']
# []
# ['BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS']
# ['REUTERS']
# ['REUTERS', 'REUTERS', 'SYDNEY']
# ['BREAKING']
# []
# ['REUTERS', 'REUTERS', 'MADRID']
# []
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'IATA', 'IATA', 'REUTERS', 'FILE', 'PHOTO', 'IATA', 'IATA', 'REUTERS', 'IATA', 'IATA', 'IATA']
# ['REUTERS', 'REUTERS', 'FRANCISCO', 'UBER', 'CODES', 'CONDUCT']
# ['RZIM', 'RZIM', 'RZIM', 'RZIM']
# []
# ['ISIS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'JERUSALEM', 'RIYADH', 'INTELLIGENCE', 'SHARING']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# []
# ['REUTERS', 'REUTERS', 'KYOTO']
# ['REUTERS', 'UNITED', 'STATES', 'TECH', 'REUTERS', 'UNITED', 'STATES', 'TECH', 'BEIJING', 'SHANGHAI', 'DARK', 'INTENTIONS']
# ['JAMA']
# ['REUTERS']
# ['REACTION', 'KPIX']
# []
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'BENGALURU', 'ECILT', 'INIP']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SYDNEY', 'AMZN', 'EBAY']
# ['ASEAN', 'ASEAN', 'ASEAN', 'ASEAN']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'HARARE', 'ZANU', 'ZANU', 'PERSONALITY', 'CULTS', 'ZANU', 'NATIONAL', 'FIGURE']
# []
# []
# ['AIDS', 'AIDS', 'AIDS', 'GRID', 'GRID', 'AIDS', 'AIDS']
# ['USDJPY', 'EURUSD']
# ['WATCH', 'CRUSHED', 'THIS']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'USMC', 'USMC', 'USMC', 'GOMER', 'STEREOTYPE']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'CARG', 'LOUDR', 'FUEL', 'PRICE', 'EFFECT', 'ABFA', 'INTL']
# []
# ['OVER']
# []
# ['ROBOTS', 'COMING', 'ROBOTS', 'COMING', "THEY'RE", 'ALREADY', 'HERE', 'LUDDITE']
# []
# ['FILE', 'PHOTO', "BBC'", 'REUTERS', 'FILE', 'PHOTO', "BBC'", 'REUTERS', 'LONDON']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'TORONTO', 'OPEC']
# []
# ['KIPP', 'USAF', 'NTTR', 'RAND']
# ['JUST', 'WATCHED', 'MUST', 'WATCH']
# ['UPROAR', 'MSNBC', 'THIS', 'READ', 'MORE', 'HERE']
# ['DJIA', 'FAANG', 'FAANG', 'AMZN', 'AAPL', 'NFLX', 'GOOG', 'GOOGL']
# []
# []
# []
# ['READ', 'MORE']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'TOKYO']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# ['REUTERS', 'REUTERS', 'MOSCOW']
# ['SHARES', 'ANOTHER', 'NOTHING']
# []
# ['DEVELOPING', 'ISIS', 'ISIS']
# []
# []
# []
# ['REUTERS', 'REUTERS', 'TOKYO']
# ['REUTERS']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS']
# []
# ['LEADER', 'MAJOR']
# []
# []
# ['SPECIAL', 'POST', 'JACK', 'LUMBERJACK']
# ['REAL', 'RAILROAD', 'CIRCUS', 'ELEPHANTS', 'COUNT', 'JUST', 'WATCHED', 'MUST', 'WATCH', 'USDA', 'JUST', 'WATCHED', 'MUST', 'WATCH']
# ['REUTERS', 'REUTERS', 'ANGELES', 'RACE']
# ['REUTERS', 'REUTERS', 'PHNOM', 'PENH']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'UNITED', 'NATIONS']
# []
# []
# ['BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS', 'BRICS']
# ['FIFA', 'EVOLUTION', 'MERCADO', 'NACIONAL', 'ARGENTINO', 'MERCADO', 'INTERNACIONAL', 'EUROPEU', 'LISTAS', 'MERCADO', 'MAIS', 'MERCADO', 'LIBERTADORES', 'CAMPEONATO', 'ESPANHOL', 'FUTEBOL', 'BRASILEIRO']
# []
# ['AIDS']
# ['MARTA', 'MARTA']
# ['JUST']
# ['DAPL']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'INTC']
# []
# []
# ['REUTERS', 'REUTERS', 'BRUSSELS', 'BRIEF', 'ENCOUNTER']
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'FRANKFURT']
# ['REUTERS', 'REUTERS', 'DELHI', 'KOLKATA', 'LALBAZAR', 'STREET', 'KOLKATA', 'FRAUD', 'EMBEZZLEMENT', 'KOLKATA']
# ['REUTERS', 'REUTERS', 'BUCHAREST', 'CENTRAL', 'EUROPE', 'DIVIDE']
# []
# ['NYSE', 'REUTERS', 'NYSE', 'REUTERS', 'YORK', 'GDAXI', 'MSCI', 'IXIC', 'EURJPY']
# []
# ['HILABI']
# ['REUTERS']
# ['MSNBC']
# []
# ['WASHINGTON']
# ['REUTERS', 'REUTERS', 'TORONTO']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIJING', 'CCTV', 'PBOC', 'MHURD', 'CCTV', 'CCTV', 'CCTV']
# ['GIANT', 'KATY', 'PERRY']
# ["BBC'"]
# ['REUTERS', 'REUTERS', 'YORK', 'COST']
# []
# ['PORTLAND']
# ['FILE', 'PHOTO', 'FOMC', 'REUTERS', 'FILE', 'PHOTO', 'FOMC', 'REUTERS', 'WASHINGTON']
# ['REUTERS', 'REUTERS', 'QCOM', 'NXPI', 'AAPL', 'AVGO']
# []
# ['SCOTUS']
# []
# ['REUTERS', 'REUTERS', 'WASHINGTON', 'ATSC', 'ATSC', 'ATSC']
# []
# ['LGBT']
# ['BUILD', 'WALL']
# []
# ['REUTERS', 'REUTERS', 'UNITED', 'NATIONS']
# ['DACA', 'DACA', 'USCIS', 'DACA', 'USCIS', 'CHIRLA', 'DACA', 'DACA', 'USCIS', 'DACA', 'DACA', 'DACA', 'DACA', 'DACA', 'DACA', 'DACA', 'DACA', 'DACA', 'CHIRLA', 'DREAM']
# ['REUTERS', 'REUTERS', 'CHICAGO', 'AMZN', 'EBITDA']
# ['REUTERS', 'REUTERS', 'DUBLIN']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'SPECULATORS', 'GAMBLERS']
# []
# ['BTCUSD', 'SPECIAL', 'REPORT', 'BITCOIN', 'BLITZ', 'INVESTING', 'NEWS', 'TRENDS', 'FAANG', 'FAANG', 'CAPE']
# ['SALT']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'PHNOM', 'PENH', 'CCHR', 'CCHR']
# ['OPEC', 'REUTERS', 'OPEC', 'REUTERS', 'DHABI', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BERLIN']
# ['EXACTLY']
# []
# ['NYPD', 'NYPD', 'NYPD']
# []
# ['MUNIR', 'ZAMAN', 'MUNIR', 'ZAMAN']
# []
# ['REUTERS', 'REUTERS', 'YORK']
# []
# ['REUTERS', 'REUTERS', 'YORK']
# ['LGBTQ', 'LGBTQ', 'LGBTQ', 'LGBTQ', 'LGBT']
# []
# []
# ['MSNBC']
# ['REUTERS', 'REUTERS', 'BEIJING']
# ['JGAP', 'JGAP']
# []
# []
# []
# ['CNBC']
# ['TODAY', 'TODAY']
# []
# []
# ['REUTERS', 'REUTERS']
# []
# ['POLITICO', 'POLITICO', 'POLITICO']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'DETROIT']
# ['PHOTO', 'PHOTO', 'UNESCO', 'PHOTO']
# ['SUBSCRIBE']
# ['IMPORTANT', 'NOTE']
# ['REUTERS']
# ['PREPA', 'FEMA']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'SEOUL']
# ['COPD', 'COPD', 'PCRM', 'USDA', 'USDA', 'PCRM', 'USDA']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'BEIJING', 'FCHA']
# []
# ['UNESCO', 'ACLU']
# []
# []
# ['WOTUS', 'FOIA', 'FOIA', 'FOIA']
# ['ESPN']
# ['BREAKING', 'OVERNIGHT']
# ['AMEN']
# []
# []
# ['REUTERS', 'REUTERS', 'BEIRUT']
# []
# []
# []
# []
# ['SAMPLE']
# []
# ['THAT']
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON', 'TSCO', 'UNSHAKEABLE', 'GRIP', 'SBRY', 'MCLSM', 'CALLS', 'HIGHER', 'PRICE']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'BEIJING', 'HONG', 'KONG', 'PBOC', 'PBOC', 'PBOC', 'PBOC']
# []
# ['WWII', 'WWII', 'WWII']
# ['JUST']
# []
# ['LIFE', 'VOICES']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'BEIRUT', 'IRNA', 'IRNA', 'UNCERTAINTY']
# ['CLARIFICATION', 'ISIS', 'BRIAN', 'EVERY', 'SHOOTER', 'TEAPARTY', 'ROSS']
# ['MOSCOW']
# ['PRRI', 'LGBT', 'PRRI']
# []
# ['VIDEO']
# []
# ['BREAKING']
# []
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MUMBAI', 'GOVERNANCE', 'ISSUES']
# ['ANON', 'JEKLOY']
# []
# []
# []
# []
# ['REUTERS', 'REUTERS', 'UBER']
# []
# ['APEC', 'REUTERS', 'APEC', 'REUTERS', 'DANANG', 'ASEAN', 'APEC']
# ['LGBT', 'LGBTQ', 'LGBTQ', 'NCTE', 'LGBT', 'LGBT', 'NCTE']
# []
# []
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'JERUSALEM']
# ['REUTERS', 'REUTERS']
# ['REUTERS', 'REUTERS', 'STRASBOURG']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'MUMBAI', 'AMZN', 'EBAY', 'MSFT']
# ['REUTERS', 'REUTERS', 'OTTAWA', 'CONSUMPTION']
# []
# []
# ['BUILD', 'WALL']
# []
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'DUBLIN']
# []
# ['JUST']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'HOUSTON', 'LONDON', 'TOTF', 'SHORT', 'SIGHTED', 'STRATEGY', 'TSLA', 'SMALL', 'SCALE', 'RENEWABLES', 'INVESTMENTS', 'BATTERY', 'POWERED', 'CARS', 'PLANES', 'JBLU']
# ['TODAY', 'TODAY']
# []
# ['WFAA']
# ['FILE', 'PHOTO', 'REUTERS', 'FILE', 'PHOTO', 'REUTERS', 'LONDON']
# []
# ['REUTERS', 'REUTERS', 'LONDON']
# []
# ['OPEC', 'REUTERS', 'OPEC', 'REUTERS', 'VIENNA', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OPEC', 'OECD', 'OPEC']
# []
# ['BARENAKEDISLAM']
# ['DCEU', 'DCEU', 'DCEU']
# ['FIFA', 'FIFA', 'FIFA', 'FIFA']
# []
# []
# ['LGBTQ', 'LGBT']
# ['LAANE']
# []
# (5678, 29)

# %%
mnb_predictions = mnb_clf.predict(X_test_counts)
svm_predictions = svm_clf.predict(X_test_counts)

mnb_score = np.mean(mnb_predictions == df_test['label'])
svm_score = np.mean(svm_predictions == df_test['label'])

print("MNB: ",mnb_score)
print("SVM: ",svm_score)
# Out:
# MNB:  0.532934131737
# SVM:  0.730891158859
